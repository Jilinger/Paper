# %%
import math
import random
#Benötigte Pakete

# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib.patches import Circle 

import matplotlib.mlab as mlab
import numpy as np
import cmath
from scipy import stats

from numpy import linalg as LA
import scipy
from scipy import spatial
import time
#import tables

import os
#import h5py

from matplotlib import animation
import matplotlib
from scipy.optimize import curve_fit
from matplotlib import rc

import gc
import sys
gc.enable()
import copy

from mpl_toolkits import mplot3d
from matplotlib import rc

# %%
def distance(x1,y1,x2,y2):
    dx=x1-x2
    dy=y1-y2
    return math.hypot(dx, dy)

def e_func (x,L,a):
    return a*np.exp(-x/L)
coords=[];

# %% [markdown]
# ### Eingabe

# %%
def quad_func(t,a):
    return a*t**2

def lin_func(t,a):
    return a*t

def sublin_func(t,a,b):
    return a*t**b

def powerlaw(t,a,b):
    return a*t**(-b)

# %%
number_atoms=5000
density=0.5
r_b=2.5
radius=np.sqrt(number_atoms*r_b**2/density)

data = open("Configurations/density_"+str(np.round(density,3))+"/transport_atoms_"+str(number_atoms)+".npy","rb")
#data = open("/home/jp/Dokumente/Bachelorarbeit/Mein_paper/BwHpcCluster/Results/Transport/density_"+str(np.round(density,3))+"/atoms_"+str(number_atoms)+".npy","rb")
text_5000=np.load(data)
print(text_5000)
density_inf_5000=np.load(data)
#density_5000=np.load(data)
ipr_5000=np.load(data)
ipr_inf_5000=np.load(data)
deviation_5000=np.load(data)
deviation_inf_5000=np.load(data)
r_1_inf_5000=np.load(data)
r_2_inf_5000=np.load(data)
r_1_5000=np.load(data)
r_2_5000=np.load(data)


density_inf_S_5000=np.load(data)
#density_S_5000=np.load(data)
ipr_S_5000=np.load(data)
ipr_inf_S_5000=np.load(data)
deviation_S_5000=np.load(data)
deviation_inf_S_5000=np.load(data)
r_1_inf_S_5000=np.load(data)
r_2_inf_S_5000=np.load(data)
r_1_S_5000=np.load(data)
r_2_S_5000=np.load(data)

data.close()


deviation_5000 = np.sqrt(deviation_5000)
deviation_S_5000 = np.sqrt(deviation_S_5000)
deviation_inf_5000 = np.sqrt(deviation_inf_5000)
deviation_inf_S_5000 = np.sqrt(deviation_inf_S_5000)
# Out:
# density=0.5, number_atoms=5000, average iterations=10, radius=250.0, r_b=2.5

# %%
number_atoms=3000
density=0.3
r_b=2.5
radius=np.sqrt(number_atoms*r_b**2/density)

data = open("Configurations/density_"+str(np.round(density,3))+"/transport_atoms_"+str(number_atoms)+".npy","rb")
#data = open("/home/jp/Dokumente/Bachelorarbeit/Mein_paper/BwHpcCluster/Results/Transport/density_"+str(np.round(density,3))+"/atoms_"+str(number_atoms)+".npy","rb")
text_3000=np.load(data)
print(text_3000)
density_inf_3000=np.load(data)
ipr_3000=np.load(data)
ipr_inf_3000=np.load(data)
deviation_3000=np.load(data)
deviation_inf_3000=np.load(data)
r_1_inf_3000=np.load(data)
r_2_inf_3000=np.load(data)
r_1_3000=np.load(data)
r_2_3000=np.load(data)
n_intervall_inf_3000=np.load(data)

density_inf_S_3000=np.load(data)
ipr_S_3000=np.load(data)
ipr_inf_S_3000=np.load(data)
deviation_S_3000=np.load(data)
deviation_inf_S_3000=np.load(data)
r_1_inf_S_3000=np.load(data)
r_2_inf_S_3000=np.load(data)
r_1_S_3000=np.load(data)
r_2_S_3000=np.load(data)
n_intervall_inf_S_3000=np.load(data)

data.close()



deviation_3000 = np.sqrt(deviation_3000)
deviation_S_3000 = np.sqrt(deviation_S_3000)
deviation_inf_3000 = np.sqrt(deviation_inf_3000)
deviation_inf_S_3000 = np.sqrt(deviation_inf_S_3000)
# Out:
# density=0.3, number_atoms=3000, average iterations=30, radius=250.0, r_b=2.5

# %%
number_atoms=2000
density=0.2
r_b=2.5
radius=np.sqrt(number_atoms*r_b**2/density)

data = open("Configurations/density_"+str(np.round(density,3))+"/transport_atoms_"+str(number_atoms)+".npy","rb")
#data = open("/home/jp/Dokumente/Bachelorarbeit/Mein_paper/BwHpcCluster/Results/Transport/density_"+str(np.round(density,3))+"/atoms_"+str(number_atoms)+".npy","rb")
text_2000=np.load(data)
print(text_2000)
density_inf_2000=np.load(data)
#density_2000=np.load(data)
ipr_2000=np.load(data)
ipr_inf_2000=np.load(data)
deviation_2000=np.load(data)
deviation_inf_2000=np.load(data)
r_1_inf_2000=np.load(data)
r_2_inf_2000=np.load(data)
r_1_2000=np.load(data)
r_2_2000=np.load(data)
n_intervall_inf_2000=np.load(data)

density_inf_S_2000=np.load(data)
#density_S_2000=np.load(data)
ipr_S_2000=np.load(data)
ipr_inf_S_2000=np.load(data)
deviation_S_2000=np.load(data)
deviation_inf_S_2000=np.load(data)
r_1_inf_S_2000=np.load(data)
r_2_inf_S_2000=np.load(data)
r_1_S_2000=np.load(data)
r_2_S_2000=np.load(data)
n_intervall_inf_S_2000=np.load(data)
data.close()



deviation_2000 = np.sqrt(deviation_2000)
deviation_S_2000 = np.sqrt(deviation_S_2000)
deviation_inf_2000 = np.sqrt(deviation_inf_2000)
deviation_inf_S_2000 = np.sqrt(deviation_inf_S_2000)
# Out:
# density=0.2, number_atoms=2000, average iterations=500, radius=250.0, r_b=2.5

# %%
number_atoms=1000
density=0.1
r_b=2.5
radius=np.sqrt(number_atoms*r_b**2/density)

data = open("Configurations/density_"+str(np.round(density,3))+"/transport_atoms_"+str(number_atoms)+".npy","rb")
#data = open("/home/jp/Dokumente/Bachelorarbeit/Mein_paper/BwHpcCluster/Results/Transport/density_"+str(np.round(density,3))+"/atoms_"+str(number_atoms)+".npy","rb")
text_1000=np.load(data)
print(text_1000)
density_inf_1000=np.load(data)
#density_1000=np.load(data)
ipr_1000=np.load(data)
ipr_inf_1000=np.load(data)
deviation_1000=np.load(data)
deviation_inf_1000=np.load(data)
r_1_inf_1000=np.load(data)
r_2_inf_1000=np.load(data)
r_1_1000=np.load(data)
r_2_1000=np.load(data)
n_intervall_inf_1000=np.load(data)

density_inf_S_1000=np.load(data)
#density_S_1000=np.load(data)
ipr_S_1000=np.load(data)
ipr_inf_S_1000=np.load(data)
deviation_S_1000=np.load(data)
deviation_inf_S_1000=np.load(data)
r_1_inf_S_1000=np.load(data)
r_2_inf_S_1000=np.load(data)
r_1_S_1000=np.load(data)
r_2_S_1000=np.load(data)
n_intervall_inf_S_1000=np.load(data)

data.close()


deviation_1000 = np.sqrt(deviation_1000)
deviation_S_1000 = np.sqrt(deviation_S_1000)
deviation_inf_1000 = np.sqrt(deviation_inf_1000)
deviation_inf_S_1000 = np.sqrt(deviation_inf_S_1000)
# Out:
# density=0.1, number_atoms=1000, average iterations=500, radius=250.0, r_b=2.5

# %%
number_atoms=500
density=0.05
r_b=2.5
radius=np.sqrt(number_atoms*r_b**2/density)

data = open("Configurations/density_"+str(np.round(density,3))+"/transport_atoms_"+str(number_atoms)+".npy","rb")
#data = open("/home/jp/Dokumente/Bachelorarbeit/Mein_paper/BwHpcCluster/Results/Transport/density_"+str(np.round(density,3))+"/atoms_"+str(number_atoms)+".npy","rb")
text_500=np.load(data)
print(text_500)
density_inf_500=np.load(data)
#density_500=np.load(data)
ipr_500=np.load(data)
ipr_inf_500=np.load(data)
deviation_500=np.load(data)
deviation_inf_500=np.load(data)
r_1_inf_500=np.load(data)
r_2_inf_500=np.load(data)
r_1_500=np.load(data)
r_2_500=np.load(data)
n_intervall_inf_500=np.load(data)

density_inf_S_500=np.load(data)
#density_S_500=np.load(data)
ipr_S_500=np.load(data)
ipr_inf_S_500=np.load(data)
deviation_S_500=np.load(data)
deviation_inf_S_500=np.load(data)
r_1_inf_S_500=np.load(data)
r_2_inf_S_500=np.load(data)
r_1_S_500=np.load(data)
r_2_S_500=np.load(data)
n_intervall_inf_S_500=np.load(data)
data.close()



deviation_500 = np.sqrt(deviation_500)
deviation_S_500 = np.sqrt(deviation_S_500)
deviation_inf_500 = np.sqrt(deviation_inf_500)
deviation_inf_S_500 = np.sqrt(deviation_inf_S_500)
# Out:
# density=0.05, number_atoms=500, average iterations=500, radius=250.0, r_b=2.5

# %%
time_array=np.logspace(-8,-2,100)
t_end=time_array[-1]
r_max=0.5*radius**2

# %% [markdown]
# #### r_2

# %%
#color="lightblue", alpha=0.5
#color="bisque", alpha=0.5
#color="darkseagreen", alpha=0.4

plt.rc('xtick',labelsize=13)
plt.rc('ytick',labelsize=13)


from matplotlib import rc
fig, axes = plt.subplots(1,1, figsize=(8,5))  
plt.tight_layout()  
axes.set_xscale("log")
axes.set_yscale("log")
plt.xlim(10**-8,t_end+t_end)
axes.spines['right'].set_visible(False)
axes.spines['top'].set_visible(False)
for axis in ['top','bottom','left','right']:
    axes.spines[axis].set_linewidth(1.5)



popt1,pcov1 = curve_fit(quad_func,time_array[0:10],r_2_5000[0:10],p0=[5*10**15])
#popt2,pcov2 = curve_fit(lin_func,time_array[0:100],r_2_5000[30:100],p0=[5*10**15])
#plt.plot(time_array[20:117],lin_func(time_array[20:117],*popt2), label=r"$t$", color="black", linestyle = ":", linewidth=2);




axes.fill_between(time_array, r_2_5000-r_2_S_5000, r_2_5000+r_2_S_5000, color="C0", alpha=0.5)
axes.plot(time_array,r_2_5000, color="C0");
axes.fill_between(time_array, r_2_3000-r_2_S_3000, r_2_3000+r_2_S_3000,color="C1", alpha=0.4)
axes.plot(time_array,r_2_3000, color="C1");
axes.fill_between(time_array, r_2_2000-r_2_S_2000, r_2_2000+r_2_S_2000,color="C2", alpha=0.4)
axes.plot(time_array,r_2_2000, color="C2");
axes.fill_between(time_array, r_2_1000-r_2_S_1000, r_2_1000+r_2_S_1000,color="C3", alpha=0.4)
axes.plot(time_array,r_2_1000, color="C3");
axes.fill_between(time_array, r_2_500-r_2_S_500, r_2_500+r_2_S_500,color="C4", alpha=0.4)
axes.plot(time_array,r_2_500, color="C4");


axes.errorbar(t_end+t_end*0.5,r_2_inf_5000, yerr= r_2_inf_S_5000, marker ="x", label=r"$\rho=0.5$",color = "C0",capsize=2)
axes.errorbar(t_end+t_end*0.5,r_2_inf_3000, yerr= r_2_inf_S_3000, marker ="x", label=r"$\rho=0.3$",color = "C1",capsize=2)
axes.errorbar(t_end+t_end*0.5,r_2_inf_2000, yerr= r_2_inf_S_2000, marker ="x", label=r"$\rho=0.2$",color = "C2",capsize=2)
axes.errorbar(t_end+t_end*0.5,r_2_inf_1000, yerr= r_2_inf_S_1000, marker ="x", label=r"$\rho=0.1$",color = "C3",capsize=2)
axes.errorbar(t_end+t_end*0.5,r_2_inf_500, yerr= r_2_inf_S_500, marker ="x", label=r"$\rho=0.05$",color = "C4",capsize=2)



axes.plot([time_array[0],time_array[-1]],[r_max,r_max],linestyle ="--", color= "grey")
axes.text(1.5*10**-8,1.3*r_max,r"homogenous distribution $\langle r^2 \rangle_{max}$", color= "grey", fontsize=15)

plt.plot(time_array[0:20],quad_func(time_array[0:20],*popt1), label=r"$t^2$", color="black", linestyle = "--", linewidth=2);
axes.text(2*10**-8,10**2.3,r"$\propto t^2$", fontsize=15)
#axes.text(2*10**-6,2*10**4,r"$\propto t ?$", fontsize=15)
#axes.grid()

axes.set_xlabel("time [s]", fontsize=15)
axes.set_ylabel(r"$\langle r^2(t) \rangle\;\;[\mu m^2]$", fontsize=15);
axes.legend();
fig.savefig("figures/r_2.png",bbox_inches = "tight",dpi=200)
#fig.savefig("figures/over_time/r_b/r_2.pdf",bbox_inches = "tight", dpi=1200)

# %% [markdown]
# #### IPr

# %%
from matplotlib import rc
fig, axes = plt.subplots(1,1, figsize=(8,5))  
plt.tight_layout()  
#axes.set_xscale("log")
##axes.set_yscale("log")
plt.xlim(-10**-5,10**-4)
axes.spines['right'].set_visible(False)
axes.spines['top'].set_visible(False)
for axis in ['top','bottom','left','right']:
    axes.spines[axis].set_linewidth(1.5)



popt1,pcov1 = curve_fit(quad_func,time_array[0:10],ipr_5000[0:10],p0=[5*10**15])
#popt2,pcov2 = curve_fit(lin_func,time_array[0:100],ipr_5000[30:100],p0=[5*10**15])
#plt.plot(time_array[20:117],lin_func(time_array[20:117],*popt2), label=r"$t$", color="black", linestyle = ":", linewidth=2);




axes.fill_between(time_array, ipr_5000-ipr_S_5000, ipr_5000+ipr_S_5000, color="C0", alpha=0.5)
axes.plot(time_array,ipr_5000, color="C0");
axes.fill_between(time_array, ipr_3000-ipr_S_3000, ipr_3000+ipr_S_3000,color="C1", alpha=0.4)
axes.plot(time_array,ipr_3000, color="C1");
axes.fill_between(time_array, ipr_2000-ipr_S_2000, ipr_2000+ipr_S_2000,color="C2", alpha=0.4)
axes.plot(time_array,ipr_2000, color="C2");
axes.fill_between(time_array, ipr_1000-ipr_S_1000, ipr_1000+ipr_S_1000,color="C3", alpha=0.4)
axes.plot(time_array,ipr_1000, color="C3");
axes.fill_between(time_array, ipr_500-ipr_S_500, ipr_500+ipr_S_500,color="C4", alpha=0.4)
axes.plot(time_array,ipr_500, color="C4");


#axes.errorbar(t_end+t_end*0.5,ipr_inf_5000, yerr= ipr_inf_S_5000, marker ="x", label=r"$\rho=0.5$",color = "C0",capsize=2)
#axes.errorbar(t_end+t_end*0.5,ipr_inf_3000, yerr= ipr_inf_S_3000, marker ="x", label=r"$\rho=0.3$",color = "C1",capsize=2)
#axes.errorbar(t_end+t_end*0.5,ipr_inf_2000, yerr= ipr_inf_S_2000, marker ="x", label=r"$\rho=0.2$",color = "C2",capsize=2)
#axes.errorbar(t_end+t_end*0.5,ipr_inf_1000, yerr= ipr_inf_S_1000, marker ="x", label=r"$\rho=0.1$",color = "C3",capsize=2)
#axes.errorbar(t_end+t_end*0.5,ipr_inf_500, yerr= ipr_inf_S_500, marker ="x", label=r"$\rho=0.05$",color = "C4",capsize=2)
