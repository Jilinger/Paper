# %%
import math
import random
#Benötigte Pakete

# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib.patches import Circle 
import seaborn as sns
from scipy import stats

import matplotlib.mlab as mlab
import numpy as np
import cmath

from numpy import linalg as LA
import scipy
from scipy import spatial
import time
#import tables

import os
#import h5py

from matplotlib import animation
import matplotlib
from scipy.optimize import curve_fit
from matplotlib import rc

import gc
import sys
gc.enable()
import copy

from mpl_toolkits import mplot3d

# %%
fig, ax = plt.subplots(figsize=(5,5))
ax.axis('off')

ax.axis('equal')
ax.set_ylim(-8,8)
ax.set_xlim(-8,8)
ax.scatter(0,0, color="red", s=70)
circle1 = plt.Circle((0, 0), radius=1, fill=False, color="red", linestyle="--")

ax.scatter(4,0, color="blue", s=70)
circle2 = plt.Circle((4, 0), radius=1, fill=False, color="blue", linestyle="--")

ax.scatter(0,4, color="blue", s=70)
circle3 = plt.Circle((0, 4), radius=1, fill=False, color="blue", linestyle="--")

ax.scatter(2.5,3, color="blue", s=70)
circle4 = plt.Circle((2.5, 3), radius=1, fill=False, color="blue", linestyle="--")


ax.scatter(-2.3,4, color="blue", s=70)
circle5 = plt.Circle((-2.3,4), radius=1, fill=False, color="blue", linestyle="--")


ax.scatter(-4,-2, color="blue", s=70)
circle6 = plt.Circle((-4, -2), radius=1, fill=False, color="blue", linestyle="--")

ax.scatter(-1.5,2, color="blue", s=70)
circle7 = plt.Circle((-1.5, 2), radius=1, fill=False, color="blue", linestyle="--")

ax.scatter(-1,-2.5, color="blue", s=70)
circle8 = plt.Circle((-1, -2.5), radius=1, fill=False, color="blue", linestyle="--")

ax.scatter(2,-3, color="blue", s=70)
circle9 = plt.Circle((2, -3), radius=1, fill=False, color="blue", linestyle="--")

ax.scatter(-4.5,1, color="blue", s=70)
circle10 = plt.Circle((-4.5, 1), radius=1, fill=False, color="blue", linestyle="--")

ax.scatter(4,-2, color="blue", s=70)
circle11 = plt.Circle((4, -2), radius=1, fill=False, color="blue", linestyle="--")


ax.scatter(-6,6, color="blue", s=70)
circle12 = plt.Circle((-6, 6), radius=1, fill=False, color="blue", linestyle="--")

ax.scatter(6.5,4, color="blue", s=70)
circle13 = plt.Circle((6.5, 4), radius=1, fill=False, color="blue", linestyle="--")

ax.scatter(-5,-5, color="blue", s=70)
circle14 = plt.Circle((-5, -5), radius=1, fill=False, color="blue", linestyle="--")

ax.scatter(0,-6.3, color="blue", s=70)
circle15 = plt.Circle((0, -6.3), radius=1, fill=False, color="blue", linestyle="--")

ax.scatter(2.5,-6, color="blue", s=70)
circle16 = plt.Circle((2.5, -6), radius=1, fill=False, color="blue", linestyle="--")

ax.scatter(2.5,6, color="blue", s=70)
circle17 = plt.Circle((2.5, 6), radius=1, fill=False, color="blue", linestyle="--")

ax.add_artist(circle1);
ax.add_artist(circle2);
ax.add_artist(circle3);
ax.add_artist(circle4);
ax.add_artist(circle5);
ax.add_artist(circle6);
ax.add_artist(circle7);
ax.add_artist(circle8);
ax.add_artist(circle9);
ax.add_artist(circle10);
ax.add_artist(circle11);
ax.add_artist(circle12);
ax.add_artist(circle13);
ax.add_artist(circle14);
ax.add_artist(circle15);
ax.add_artist(circle16);
ax.add_artist(circle17);

ax.annotate(s='', xy=(-5.8,0), xytext=(-5.8,2), arrowprops=dict(arrowstyle='<->'))
ax.text(-6.8, 0.8, r'$r_b$', fontsize=13);

fig.savefig("figures/rydberg.png",bbox_inches = "tight",dpi=1200,transparent=True)
#fig.savefig("figures/rydberg.pdf",bbox_inches = "tight", dpi=1200)

# %%
def hexagonal(r_tmp,r_b):
    atoms =[]
    spalten=math.ceil(2*r_tmp/r_b)

    x=-r_tmp
    y= r_tmp
    s=-1
    for i in range(spalten):
        for j in range(spalten):
            if np.sqrt(x*x+y*y)<(r_tmp):
                atoms.append([x,y])
            y-=2*r_b
        x+=np.sqrt((2*r_b)**2-r_b**2)
        if s >0:
            y=r_tmp
        else:
            y=r_tmp-r_b
        s*=-1
    return np.array(atoms)

# %%
atoms= square(200,5)
prob = scipy.spatial.distance.cdist(atoms, [[0,0]], metric='euclidean')[:,0]
prob = 1/prob

atoms_2= square(300,5)
prob_2 = scipy.spatial.distance.cdist(atoms_2, [[0,0]], metric='euclidean')[:,0]
prob_2 = 1/prob_2
# Out:
# /usr/bin/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in true_divide
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/bin/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: RuntimeWarning: divide by zero encountered in true_divide
#   import sys

# %%
fig, ax = plt.subplots(figsize=(7,7))
ax.axis('off')

ax.axis('equal')
ax.set_ylim(-300,300)
ax.set_xlim(-300,300)


#ax.scatter(atoms[:,0], atoms[:,1] ,color="blue", s=10)
angeregt= np.argmin(scipy.spatial.distance.cdist(atoms, [[0,0]], metric='euclidean'))
print(atoms[angeregt])


scat2 = ax.scatter(atoms[:,0], atoms[:,1], marker='o', s=30, c=prob ,
                   norm=matplotlib.colors.LogNorm(vmin= 1/120,vmax=1/10))
ax.scatter(0,0 ,color="darkred", s=30)
plt.set_cmap('jet')


fig.savefig("figures/loc_beweis_1.pdf",bbox_inches = "tight", dpi=1200)

fig, ax = plt.subplots(figsize=(7,7))
ax.axis('off')

ax.axis('equal')
ax.set_ylim(-300,300)
ax.set_xlim(-300,300)


#ax.scatter(atoms[:,0], atoms[:,1] ,color="blue", s=10)
angeregt= np.argmin(scipy.spatial.distance.cdist(atoms_2, [[0,0]], metric='euclidean'))
print(angeregt)

scat3 = ax.scatter(atoms_2[:,0], atoms_2[:,1], marker='o', s=30, c=prob_2 ,
                   norm=matplotlib.colors.LogNorm(vmin= 1/120,vmax=1/10))
ax.scatter(0,0 ,color="darkred", s=30)
plt.set_cmap('jet')
#plt.colorbar(scat2, label="probability",ax=ax)

fig.savefig("figures/loc_beweis_2.pdf",bbox_inches = "tight", dpi=1200)
# Out:
# [0 0]
# 1404

# %%
fig, ax = plt.subplots(figsize=(7,7))
ax.axis('off')

ax.axis('equal')
ax.set_ylim(-300,300)
ax.set_xlim(-300,300)

plt.set_cmap('jet')
#ax.scatter(atoms[:,0], atoms[:,1] ,color="blue", s=10)
angeregt= np.argmin(scipy.spatial.distance.cdist(atoms, [[0,0]], metric='euclidean'))
print(atoms[angeregt])


scat2 = ax.scatter(atoms[:,0], atoms[:,1], marker='o', s=30, c=prob ,
                   norm=matplotlib.colors.LogNorm(vmin= 1/300,vmax=1/10))
ax.scatter(0,0 ,color="darkred", s=30)
plt.set_cmap('jet')
#plt.colorbar(scat2, label="probability",ax=ax)

fig.savefig("figures/deloc_beweis_1.pdf",bbox_inches = "tight", dpi=1200)

fig, ax = plt.subplots(figsize=(7,7))
ax.axis('off')

ax.axis('equal')
ax.set_ylim(-300,300)
ax.set_xlim(-300,300)


#ax.scatter(atoms[:,0], atoms[:,1] ,color="blue", s=10)
angeregt= np.argmin(scipy.spatial.distance.cdist(atoms_2, [[0,0]], metric='euclidean'))
print(angeregt)

scat3 = ax.scatter(atoms_2[:,0], atoms_2[:,1], marker='o', s=30, c=prob_2 ,
                   norm=matplotlib.colors.LogNorm(vmin= 1/300,vmax=1/10))
ax.scatter(0,0 ,color="darkred", s=30)
plt.set_cmap('jet')
#plt.colorbar(scat2, label="probability",ax=ax)


         
#ax.scatter(a1[:,0], a1[:,1], marker='o', s=30, c="darkblue")
#ax.scatter(a2[:,0], a2[:,1], marker='o', s=30, c="blue")
fig.savefig("figures/deloc_beweis_2.pdf",bbox_inches = "tight", dpi=1200)
# Out:
# [0 0]
# 1404

# %%
def square(r_tmp,r_b):
    atoms =[]
    spalten=math.ceil(2*r_tmp/r_b)

    x=-r_tmp
    y= r_tmp

    for i in range(spalten):
        for j in range(spalten):
            if np.sqrt(x*x+y*y)<(r_tmp):
                atoms.append([x,y])
            y-=2*r_b
        x+=2*r_b
   
        y=r_tmp
    
     
    return np.array(atoms)

# %%
atoms= square(50,5)
prob = scipy.spatial.distance.cdist(atoms, [[0,0]], metric='euclidean')[:,0]
prob = 1/prob

atoms_2= square(100,5)
prob_2 = scipy.spatial.distance.cdist(atoms_2, [[0,0]], metric='euclidean')[:,0]
prob_2 = 1/prob_2

atoms_3= square(200,5)
prob_3 = scipy.spatial.distance.cdist(atoms_3, [[0,0]], metric='euclidean')[:,0]
prob_3 = 1/prob_3

atoms_4= square(300,5)
prob_4 = scipy.spatial.distance.cdist(atoms_4, [[0,0]], metric='euclidean')[:,0]
prob_4 = 1/prob_4
# Out:
# /usr/bin/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in true_divide
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/bin/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: RuntimeWarning: divide by zero encountered in true_divide
#   import sys
# /usr/bin/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:11: RuntimeWarning: divide by zero encountered in true_divide
#   # This is added back by InteractiveShellApp.init_path()
# /usr/bin/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:15: RuntimeWarning: divide by zero encountered in true_divide
#   from ipykernel import kernelapp as app

# %%
fig, ax = plt.subplots(2,2, figsize=(14,14))
plt.subplots_adjust(wspace=-0.1,hspace=-0.1)

ax[0,0].axis('off')
ax[0,1].axis('off')
ax[1,0].axis('off')
ax[1,1].axis('off')

ax[0,0].axis('equal')
ax[0,0].set_ylim(-300,300)
ax[0,0].set_xlim(-300,300)


#ax.scatter(atoms[:,0], atoms[:,1] ,color="blue", s=10)
angeregt= np.argmin(scipy.spatial.distance.cdist(atoms, [[0,0]], metric='euclidean'))


scat1 = ax[0,0].scatter(atoms[:,0], atoms[:,1], marker='o', s=30, c=prob ,
                   norm=matplotlib.colors.LogNorm(vmin= 1/120,vmax=1/10))
ax[0,0].scatter(0,0 ,color="darkred", s=30)
plt.set_cmap('jet')



ax[0,1].axis('equal')
ax[0,1].set_ylim(-300,300)
ax[0,1].set_xlim(-300,300)


#ax.scatter(atoms[:,0], atoms[:,1] ,color="blue", s=10)
angeregt= np.argmin(scipy.spatial.distance.cdist(atoms_2, [[0,0]], metric='euclidean'))

scat2 = ax[0,1].scatter(atoms_2[:,0], atoms_2[:,1], marker='o', s=30, c=prob_2 ,
                   norm=matplotlib.colors.LogNorm(vmin= 1/120,vmax=1/10))
ax[0,1].scatter(0,0 ,color="darkred", s=30)
plt.set_cmap('jet')
#plt.colorbar(scat2, label="probability",ax=ax)


ax[1,0].axis('equal')
ax[1,0].set_ylim(-300,300)
ax[1,0].set_xlim(-300,300)

#ax.scatter(atoms[:,0], atoms[:,1] ,color="blue", s=10)
angeregt= np.argmin(scipy.spatial.distance.cdist(atoms_3, [[0,0]], metric='euclidean'))

scat3 = ax[1,0].scatter(atoms_3[:,0], atoms_3[:,1], marker='o', s=30, c=prob_3 ,
                   norm=matplotlib.colors.LogNorm(vmin= 1/120,vmax=1/10))
ax[1,0].scatter(0,0 ,color="darkred", s=30)
plt.set_cmap('jet')
#plt.colorbar(scat2, label="probability",ax=ax)



ax[1,1].axis('equal')
ax[1,1].set_ylim(-300,300)
ax[1,1].set_xlim(-300,300)


#ax.scatter(atoms[:,0], atoms[:,1] ,color="blue", s=10)
angeregt= np.argmin(scipy.spatial.distance.cdist(atoms_4, [[0,0]], metric='euclidean'))

scat4 = ax[1,1].scatter(atoms_4[:,0], atoms_4[:,1], marker='o', s=30, c=prob_4 ,
                   norm=matplotlib.colors.LogNorm(vmin= 1/120,vmax=1/10))
ax[1,1].scatter(0,0 ,color="darkred", s=30)
plt.set_cmap('jet')
#plt.colorbar(scat2, label="probability",ax=ax)


fig.savefig("prasi/figures/systemgroße.pdf",bbox_inches = "tight", dpi=1200)
