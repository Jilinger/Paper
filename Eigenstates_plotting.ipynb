# %%
import math
import random
#Benötigte Pakete

# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib.patches import Circle 

import matplotlib.mlab as mlab
import numpy as np
import cmath
from scipy import stats

from numpy import linalg as LA
import scipy
from scipy import spatial
import time
#import tables

import os
#import h5py

from matplotlib import animation
import matplotlib
from scipy.optimize import curve_fit
from matplotlib import rc

import gc
import sys
gc.enable()
import copy

from mpl_toolkits import mplot3d
from matplotlib import rc

# %% [markdown]
# # Einzelne Durchführung 10000 Atome

# %%
data = open("Freiburg/10000_001.npy","rb")
pr_2_001=np.load(data)
eigenvalues_001=np.load(data)

data = open("Freiburg/10000_005.npy","rb")
pr_2_005=np.load(data)
eigenvalues_005=np.load(data)

data = open("Freiburg/10000_01.npy","rb")
pr_2_01=np.load(data)
eigenvalues_01=np.load(data)

# %% [markdown]
# #### Dichte 0.01

# %%
plt.rc('xtick',labelsize=13)
plt.rc('ytick',labelsize=13)


fig, axes = plt.subplots(1,1)#, figsize=(13,18))  
plt.tight_layout()  
#axes.set_xscale("log")
#axes.set_yscale("log")

axes.spines['right'].set_visible(False)
axes.spines['top'].set_visible(False)
for axis in ['top','bottom','left','right']:
    axes.spines[axis].set_linewidth(1.5)


axes.ticklabel_format(axis="x", style="scientific",scilimits=(0,0),useMathText=True)
#axes.ticklabel_format(axis="y", style="scientific",scilimits=(0,0),useMathText=True)
    
    

axes.errorbar(eigenvalues_001,1/pr_2_001, linestyle="None", marker=".") ;   
axes.set_xlabel("Energy",fontsize=15)
axes.set_ylabel("Inverse Participation Ratio",fontsize=15);
          
        
fig.savefig("Freiburg/IPR_10000_001.pdf",bbox_inches = "tight")#, dpi=1200)



#------------------------------------------------------------------------------------------------------


fig, axes = plt.subplots(1,1)#, figsize=(13,18))  
plt.tight_layout()  
#axes.set_xscale("log")
#axes.set_yscale("log")

axes.spines['right'].set_visible(False)
axes.spines['top'].set_visible(False)
for axis in ['top','bottom','left','right']:
    axes.spines[axis].set_linewidth(1.5)


axes.ticklabel_format(axis="x", style="scientific",scilimits=(0,0),useMathText=True)
#axes.ticklabel_format(axis="y", style="scientific",scilimits=(0,0),useMathText=True)
    

axes.errorbar(eigenvalues_001,pr_2_001, linestyle="None", marker=".") ;   
axes.set_xlabel("Energy",fontsize=15)
axes.set_ylabel("Participation Ratio",fontsize=15);

fig.savefig("Freiburg/PR_10000_001.pdf",bbox_inches = "tight")

# %% [markdown]
# #### Dichte 0.05

# %%
plt.rc('xtick',labelsize=13)
plt.rc('ytick',labelsize=13)


fig, axes = plt.subplots(1,1)#, figsize=(13,18))  
plt.tight_layout()  
#axes.set_xscale("log")
#axes.set_yscale("log")

axes.spines['right'].set_visible(False)
axes.spines['top'].set_visible(False)
for axis in ['top','bottom','left','right']:
    axes.spines[axis].set_linewidth(1.5)


axes.ticklabel_format(axis="x", style="scientific",scilimits=(0,0),useMathText=True)
#axes.ticklabel_format(axis="y", style="scientific",scilimits=(0,0),useMathText=True)
    
    

axes.errorbar(eigenvalues_005,1/pr_2_005, linestyle="None", marker=".") ;   
axes.set_xlabel("Energy",fontsize=15)
axes.set_ylabel("Inverse Participation Ratio",fontsize=15);
          
        
fig.savefig("Freiburg/IPR_10000_005.pdf",bbox_inches = "tight")#, dpi=1200)



#------------------------------------------------------------------------------------------------------


fig, axes = plt.subplots(1,1)#, figsize=(13,18))  
plt.tight_layout()  
#axes.set_xscale("log")
#axes.set_yscale("log")

axes.spines['right'].set_visible(False)
axes.spines['top'].set_visible(False)
for axis in ['top','bottom','left','right']:
    axes.spines[axis].set_linewidth(1.5)


axes.ticklabel_format(axis="x", style="scientific",scilimits=(0,0),useMathText=True)
#axes.ticklabel_format(axis="y", style="scientific",scilimits=(0,0),useMathText=True)
    

axes.errorbar(eigenvalues_005,pr_2_005, linestyle="None", marker=".") ;   
axes.set_xlabel("Energy",fontsize=15)
axes.set_ylabel("Participation Ratio",fontsize=15);

fig.savefig("Freiburg/PR_10000_005.pdf",bbox_inches = "tight")

# %% [markdown]
# #### Dichte 0.1

# %%
plt.rc('xtick',labelsize=13)
plt.rc('ytick',labelsize=13)


fig, axes = plt.subplots(1,1)#, figsize=(13,18))  
plt.tight_layout()  
#axes.set_xscale("log")
#axes.set_yscale("log")

axes.spines['right'].set_visible(False)
axes.spines['top'].set_visible(False)
for axis in ['top','bottom','left','right']:
    axes.spines[axis].set_linewidth(1.5)


axes.ticklabel_format(axis="x", style="scientific",scilimits=(0,0),useMathText=True)
#axes.ticklabel_format(axis="y", style="scientific",scilimits=(0,0),useMathText=True)
    
    

axes.errorbar(eigenvalues_01,1/pr_2_01, linestyle="None", marker=".") ;   
axes.set_xlabel("Energy",fontsize=15)
axes.set_ylabel("Inverse Participation Ratio",fontsize=15);
          
        
#fig.savefig("Freiburg/IPR_10000_01.pdf",bbox_inches = "tight")#, dpi=1200)



#------------------------------------------------------------------------------------------------------


fig, axes = plt.subplots(1,1)#, figsize=(13,18))  
plt.tight_layout()  
#axes.set_xscale("log")
#axes.set_yscale("log")

axes.spines['right'].set_visible(False)
axes.spines['top'].set_visible(False)
for axis in ['top','bottom','left','right']:
    axes.spines[axis].set_linewidth(1.5)


axes.ticklabel_format(axis="x", style="scientific",scilimits=(0,0),useMathText=True)
#axes.ticklabel_format(axis="y", style="scientific",scilimits=(0,0),useMathText=True)
    

axes.errorbar(eigenvalues_01,pr_2_01, linestyle="None", marker=".") ;   
axes.set_xlabel("Energy",fontsize=15)
axes.set_ylabel("Participation Ratio",fontsize=15);

#fig.savefig("Freiburg/10000_01.pdf",bbox_inches = "tight")

# %% [markdown]
# # Messwerte aus mehreren Messungen

# %%
density= 0.1
r_b = 5
anzahl = np.array([100,500,1000,1500,2000,2500,5000,7500,10000,12500,15000])
radiusse = (np.sqrt(anzahl*r_b**2/density))

# %%
eigenvalues=[[] for i in range(len(anzahl))]
ipr=[[] for i in range(len(anzahl))]
ipr_q=[[] for i in range(len(anzahl))]

i=0

density=0.1
for number_atoms, radius in zip(anzahl,radiusse):  
    data = open("/home/jp/Dokumente/Bachelorarbeit/Mein_paper/BwHpcCluster/Results/Fractality/different_q/density_"+str(np.round(density,3))+"/atoms_"+str(number_atoms)+".npy","rb")
    
    ipr[i]=np.load(data)
    eigenvalues[i]=np.load(data)
    i+=1
    
ipr=np.array(ipr)
eigenvalues=np.array(eigenvalues)

# %%
plot=10
print("number_atoms für plot:", anzahl[plot])

plt.rc('xtick',labelsize=13)
plt.rc('ytick',labelsize=13)


fig, axes = plt.subplots(1,1)#, figsize=(13,18))  
plt.tight_layout()  
#axes.set_xscale("log")
#axes.set_yscale("log")

axes.spines['right'].set_visible(False)
axes.spines['top'].set_visible(False)
for axis in ['top','bottom','left','right']:
    axes.spines[axis].set_linewidth(1.5)


axes.ticklabel_format(axis="x", style="scientific",scilimits=(0,0),useMathText=True)
#axes.ticklabel_format(axis="y", style="scientific",scilimits=(0,0),useMathText=True)
    
    

axes.errorbar(eigenvalues[plot],ipr[plot], linestyle="None", marker=".") ;   
axes.set_xlabel("Energy",fontsize=15)
axes.set_ylabel("Inverse Participation Ratio",fontsize=15);
          
        
fig.savefig("Freiburg/IPR_15000_01.png",bbox_inches = "tight", dpi=500)



#------------------------------------------------------------------------------------------------------


fig, axes = plt.subplots(1,1)#, figsize=(13,18))  
plt.tight_layout()  
#axes.set_xscale("log")
#axes.set_yscale("log")

axes.spines['right'].set_visible(False)
axes.spines['top'].set_visible(False)
for axis in ['top','bottom','left','right']:
    axes.spines[axis].set_linewidth(1.5)


axes.ticklabel_format(axis="x", style="scientific",scilimits=(0,0),useMathText=True)
#axes.ticklabel_format(axis="y", style="scientific",scilimits=(0,0),useMathText=True)
    

axes.errorbar(eigenvalues[plot],1/ipr[plot], linestyle="None", marker=".") ;   
axes.set_xlabel("Energy",fontsize=15)
axes.set_ylabel("Participation Ratio",fontsize=15);

fig.savefig("Freiburg/15000_01.png",bbox_inches = "tight",dpi=500)
# Out:
# number_atoms für plot: 15000

# %% [markdown]
# #### Dichte 0.05

# %%
density= 0.05
r_b = 5
anzahl = np.arange(100,1000,100)
radiusse = (np.sqrt(anzahl*r_b**2/density))

# %%
eigenvalues=[[] for i in range(len(anzahl))]
ipr=[[] for i in range(len(anzahl))]
ipr_q=[[] for i in range(len(anzahl))]

i=0

density=0.1
for number_atoms, radius in zip(anzahl,radiusse):  
    data = open("/home/jp/Dokumente/Bachelorarbeit/Mein_paper/Überarbeitung/final_files/fractality/density_0.05/"+str(number_atoms)+"_"+str(int(radius))+".npy","rb")
    
    ipr[i]=np.load(data)
    np.load(data)
    eigenvalues[i]=np.load(data)

    i+=1
    
    
ipr=np.array(ipr)
eigenvalues=np.array(eigenvalues)

# %%
plot=5
print("number_atoms für plot:", anzahl[plot])

plt.rc('xtick',labelsize=13)
plt.rc('ytick',labelsize=13)


fig, axes = plt.subplots(1,1)#, figsize=(13,18))  
plt.tight_layout()  
#axes.set_xscale("log")
#axes.set_yscale("log")

axes.spines['right'].set_visible(False)
axes.spines['top'].set_visible(False)
for axis in ['top','bottom','left','right']:
    axes.spines[axis].set_linewidth(1.5)


axes.ticklabel_format(axis="x", style="scientific",scilimits=(0,0),useMathText=True)
#axes.ticklabel_format(axis="y", style="scientific",scilimits=(0,0),useMathText=True)
    
    

axes.errorbar(eigenvalues[plot],ipr[plot], linestyle="None", marker=".") ;   
axes.set_xlabel("Energy",fontsize=15)
axes.set_ylabel("Inverse Participation Ratio",fontsize=15);
          
        
fig.savefig("Freiburg/IPR_600_005.png",bbox_inches = "tight",dpi=200)



#------------------------------------------------------------------------------------------------------


fig, axes = plt.subplots(1,1)#, figsize=(13,18))  
plt.tight_layout()  
#axes.set_xscale("log")
#axes.set_yscale("log")

axes.spines['right'].set_visible(False)
axes.spines['top'].set_visible(False)
for axis in ['top','bottom','left','right']:
    axes.spines[axis].set_linewidth(1.5)


axes.ticklabel_format(axis="x", style="scientific",scilimits=(0,0),useMathText=True)
#axes.ticklabel_format(axis="y", style="scientific",scilimits=(0,0),useMathText=True)
    

axes.errorbar(eigenvalues[plot],1/ipr[plot], linestyle="None", marker=".") ;   
axes.set_xlabel("Energy",fontsize=15)
axes.set_ylabel("Participation Ratio",fontsize=15);

fig.savefig("Freiburg/600_005.png",bbox_inches = "tight",dpi=200)
# Out:
# number_atoms für plot: 600
