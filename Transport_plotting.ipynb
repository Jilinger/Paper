# %%
import math
import random
#Benötigte Pakete

# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib.patches import Circle 

import matplotlib.mlab as mlab
import numpy as np
import cmath
from scipy import stats

from numpy import linalg as LA
import scipy
from scipy import spatial
import time
#import tables

import os
#import h5py

from matplotlib import animation
import matplotlib
from scipy.optimize import curve_fit
from matplotlib import rc

import gc
import sys
gc.enable()
import copy

from mpl_toolkits import mplot3d
from matplotlib import rc

# %%
def distance(x1,y1,x2,y2):
    dx=x1-x2
    dy=y1-y2
    return math.hypot(dx, dy)

def e_func (x,L,a):
    return a*np.exp(-x/L)
coords=[];

# %% [markdown]
# ### Eingabe

# %%
def quad_func(t,a):
    return a*t**2

def lin_func(t,a):
    return a*t

def sublin_func(t,a,b):
    return a*t**b

def powerlaw(t,a,b):
    return a*t**(-b)

# %%
R=np.sqrt(15000*5**2/0.5)
dens=np.array([0.2,0.05,0.01])
print(R)
N=dens*R**2/5**2
print(N)
# Out:
# 866.0254037844386
# [6000. 1500.  300.]

# %%
number_atoms=15000
density=0.5
radius=np.sqrt(number_atoms*5**2/density)
r_b=5

data = open("Results/Transport/density_"+str(np.round(density,3))+"/atoms_"+str(number_atoms)+".npy","rb")
text_15000=np.load(data)
print(text_15000)
density_inf_15000=np.load(data)
density_15000=np.load(data)
ipr_15000=np.load(data)
ipr_inf_15000=np.load(data)
deviation_15000=np.load(data)
deviation_inf_15000=np.load(data)
r_1_inf_15000=np.load(data)
r_2_inf_15000=np.load(data)
r_1_15000=np.load(data)
r_2_15000=np.load(data)


density_inf_S_15000=np.load(data)
density_S_15000=np.load(data)
ipr_S_15000=np.load(data)
ipr_inf_S_15000=np.load(data)
deviation_S_15000=np.load(data)
deviation_inf_S_15000=np.load(data)
r_1_inf_S_15000=np.load(data)
r_2_inf_S_15000=np.load(data)
r_1_S_15000=np.load(data)
r_2_S_15000=np.load(data)

data.close()




deviation_15000 = np.sqrt(deviation_15000)
deviation_S_15000 = np.sqrt(deviation_S_15000)
deviation_inf_15000 = np.sqrt(deviation_inf_15000)
deviation_inf_S_15000 = np.sqrt(deviation_inf_S_15000)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-650ecee52af4> in <module>
#       4 r_b=5
#       5
# ----> 6 data = open("Results/Transport/density_"+str(np.round(density,3))+"/atoms_"+str(number_atoms)+".npy","rb")
#       7 text_15000=np.load(data)
#       8 print(text_15000)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Results/Transport/density_0.5/atoms_15000.npy'

# %%
number_atoms=6000
density=0.2
radius=np.sqrt(number_atoms*5**2/density)
r_b=5

data= open("Results/Transport/density_"+str(np.round(density,3))+"/atoms_"+str(number_atoms)+".npy","rb")
text_6000=np.load(data)
print(text_6000)
density_inf_6000=np.load(data)
density_6000=np.load(data)
ipr_6000=np.load(data)
ipr_inf_6000=np.load(data)
deviation_6000=np.load(data)
deviation_inf_6000=np.load(data)
r_1_inf_6000=np.load(data)
r_2_inf_6000=np.load(data)
r_1_6000=np.load(data)
r_2_6000=np.load(data)


density_inf_S_6000=np.load(data)
density_S_6000=np.load(data)
ipr_S_6000=np.load(data)
ipr_inf_S_6000=np.load(data)
deviation_S_6000=np.load(data)
deviation_inf_S_6000=np.load(data)
r_1_inf_S_6000=np.load(data)
r_2_inf_S_6000=np.load(data)
r_1_S_6000=np.load(data)
r_2_S_6000=np.load(data)

data.close()

deviation_6000 = np.sqrt(deviation_6000)
deviation_S_6000 = np.sqrt(deviation_S_6000)
deviation_inf_6000 = np.sqrt(deviation_inf_6000)
deviation_inf_S_6000 = np.sqrt(deviation_inf_S_6000)
# Out:
# density=0.2, number_atoms=6000, average iterations=500, radius=866.025403784, r_b=5

# %%
number_atoms=1500
density=0.05
radius=np.sqrt(number_atoms*5**2/density)
r_b=5

data = open("Results/Transport/density_"+str(np.round(density,3))+"/atoms_"+str(number_atoms)+".npy","rb")
text_1500=np.load(data)
print(text_1500)
density_inf_1500=np.load(data)
density_1500=np.load(data)
ipr_1500=np.load(data)
ipr_inf_1500=np.load(data)
deviation_1500=np.load(data)
deviation_inf_1500=np.load(data)
r_1_inf_1500=np.load(data)
r_2_inf_1500=np.load(data)
r_1_1500=np.load(data)
r_2_1500=np.load(data)


density_inf_S_1500=np.load(data)
density_S_1500=np.load(data)
ipr_S_1500=np.load(data)
ipr_inf_S_1500=np.load(data)
deviation_S_1500=np.load(data)
deviation_inf_S_1500=np.load(data)
r_1_inf_S_1500=np.load(data)
r_2_inf_S_1500=np.load(data)
r_1_S_1500=np.load(data)
r_2_S_1500=np.load(data)

data.close()

deviation_1500 = np.sqrt(deviation_1500)
deviation_S_1500 = np.sqrt(deviation_S_1500)
deviation_inf_1500 = np.sqrt(deviation_inf_1500)
deviation_inf_S_1500 = np.sqrt(deviation_inf_S_1500)

r_2_S_1500/=1.5
r_2_inf_S_1500/=1.5
# Out:
# density=0.05, number_atoms=1500, average iterations=5000, radius=866.025403784, r_b=5

# %%
number_atoms=300
density=0.01
radius=np.sqrt(number_atoms*5**2/density)
r_b=5

data = open("Results/Transport/density_"+str(np.round(density,3))+"/atoms_"+str(number_atoms)+".npy","rb")
text_300=np.load(data)
print(text_300)
density_inf_300=np.load(data)
density_300=np.load(data)
ipr_300=np.load(data)
ipr_inf_300=np.load(data)
deviation_300=np.load(data)
deviation_inf_300=np.load(data)
r_1_inf_300=np.load(data)
r_2_inf_300=np.load(data)
r_1_300=np.load(data)
r_2_300=np.load(data)


density_inf_S_300=np.load(data)
density_S_300=np.load(data)
ipr_S_300=np.load(data)
ipr_inf_S_300=np.load(data)
deviation_S_300=np.load(data)
deviation_inf_S_300=np.load(data)
r_1_inf_S_300=np.load(data)
r_2_inf_S_300=np.load(data)
r_1_S_300=np.load(data)
r_2_S_300=np.load(data)

data.close()

deviation_300 = np.sqrt(deviation_300)
deviation_S_300 = np.sqrt(deviation_S_300)
deviation_inf_300 = np.sqrt(deviation_inf_300)
deviation_inf_S_300 = np.sqrt(deviation_inf_S_300)

r_2_S_300/=1.5
r_2_inf_S_300/=1.5
# Out:
# density=0.01, number_atoms=300, average iterations=20000, gebrauchte Zeit=2022.2486443519592, radius=866.025403784, r_b=5

# %%
times=np.logspace(-8,-2,150)
t_end=times[-1]
r_max=0.5*radius**2

# %%
#color="lightblue", alpha=0.5
#color="bisque", alpha=0.5
#color="darkseagreen", alpha=0.4

plt.rc('xtick',labelsize=13)
plt.rc('ytick',labelsize=13)


from matplotlib import rc
fig, axes = plt.subplots(1,1, figsize=(8,5))  
plt.tight_layout()  
axes.set_xscale("log")
axes.set_yscale("log")
plt.xlim(left=10**-8, right=1.7*10**-2)
plt.ylim(0.1,10**6)
axes.spines['right'].set_visible(False)
axes.spines['top'].set_visible(False)
for axis in ['top','bottom','left','right']:
    axes.spines[axis].set_linewidth(1.5)



#popt1,pcov1 = curve_fit(quad_func,times[0:10],r_2_15000[0:10],p0=[5*10**15])
popt2,pcov2 = curve_fit(lin_func,times[30:100],r_2_6000[30:100],p0=[5*10**15])
#plt.plot(times[0:20],quad_func(times[0:20],*popt1), label=r"$t^2$", color="black", linestyle = "--", linewidth=2);
plt.plot(times[20:117],lin_func(times[20:117],*popt2), label=r"$t$", color="black", linestyle = ":", linewidth=2);



#axes.fill_between(times, r_2_15000-r_2_S_15000, r_2_15000+r_2_S_15000, color="lightblue", alpha=0.5)
#axes.plot(times,r_2_15000);
axes.fill_between(times, r_2_6000-r_2_S_6000, r_2_6000+r_2_S_6000, color="bisque", alpha=0.5)
axes.plot(times,r_2_6000);
axes.fill_between(times, r_2_1500-r_2_S_1500, r_2_1500+r_2_S_1500,color="darkseagreen", alpha=0.4)
axes.plot(times,r_2_1500);
axes.fill_between(times, r_2_300-r_2_S_300, r_2_300+r_2_S_300,color="darkseagreen", alpha=0.4)
axes.plot(times,r_2_300);

#axes.errorbar(t_end+t_end*0.5,r_2_inf_5000, yerr= r_2_inf_5000_S, marker ="x", label=r"$r_b=10 \;\mu m$",color = "C0",capsize=2)
axes.errorbar(t_end+t_end*0.5,r_2_inf_6000, yerr= r_2_inf_S_6000, marker ="x", label=r"$\rho=0.2$",color = "C1",capsize=2)
axes.errorbar(t_end+t_end*0.5,r_2_inf_1500, yerr= r_2_inf_S_1500, marker ="x", label=r"$\rho=0.05$",color = "C2",capsize=2)
axes.errorbar(t_end+t_end*0.5,r_2_inf_300, yerr= r_2_inf_S_300, marker ="x", label=r"$\rho=0.01$",color = "C2",capsize=2)



axes.plot([10**-8,1.7*10**-2],[r_max,r_max],linestyle ="--", color= "grey")
axes.text(1.5*10**-8,1.3*r_max,r"homogenous distribution $\langle r^2 \rangle_{max}$", color= "grey", fontsize=15)
axes.text(2*10**-7,10**3,r"$\propto t^2$", fontsize=15)
axes.text(2*10**-6,2*10**4,r"$\propto t ?$", fontsize=15)
#axes.grid()

axes.set_xlabel("time [s]", fontsize=15)
axes.set_ylabel(r"$\langle r^2(t) \rangle\;\;[\mu m^2]$", fontsize=15);
axes.legend();
#fig.savefig("figures/over_time/r_b/r_2.png",bbox_inches = "tight",dpi=200)
#fig.savefig("figures/over_time/r_b/r_2.pdf",bbox_inches = "tight", dpi=1200)

# %% [markdown]
# ### Hohe Dichte 0.5

# %%
# plots ---------------------------------------------------------------------------------------------

r_b =5




fig, axes = plt.subplots(5,2, figsize=(13,18))  # 2 rows, 2 columns
plt.tight_layout()  
plt.subplots_adjust(wspace=0.2)

axes[0,0].set_title("probability accumulation")
axes[0,0].plot(x_3200,n_ursprung_inf_3200, label="infinite time - 3200");
axes[0,0].plot(x_5000,n_ursprung_inf_5000, label="infinite time - 5000");
axes[0,0].plot(x_7200,n_ursprung_inf_7200, label="infinite time - 7200");
axes[0,0].set_xlabel("Abstand")
axes[0,0].set_ylabel("Wahrscheinlichkeit")
#axes[0,0].set_yscale("log")
axes[0,0].legend();





# Hide the right and top spines
axes[0,0].spines['right'].set_visible(False)
axes[0,0].spines['top'].set_visible(False)
#axes[0,0].grid()

# Only show ticks on the left and bottom spines
#axes[0,0].yaxis.set_ticks_position('left')
#axes[0,0].xaxis.set_ticks_position('bottom')

#axes[0,1].set_title("Ausbreitung")
#axes[0,1].plot(x[:len(n_intervall[0])],n_intervall[0], label="Zeit=0");
#axes[0,1].plot(x[:len(n_intervall[1])],n_intervall[1], label = "Zeit = 1");
#axes[0,1].plot(x[:len(n_intervall[2])],n_intervall[2], label = "Zeit = 5");
#axes[0,1].plot(x[:len(n_intervall[3])],n_intervall[3], label = "Zeit = 50");
#axes[0,1].plot(x[:len(n_intervall_inf)],n_intervall_inf, label="infinite time");
#axes[0,1].set_xlabel("Abstand")
#axes[0,1].set_ylabel("Wahrscheinlichkeit")
##axes[0,1].set_yscale("log")
#axes[0,1].set_xlim(-20,radius+20)
#axes[0,1].legend();



axes[1,0].ticklabel_format(axis="x", style="scientific",scilimits=(4,-3))
axes[1,0].set_title("standard deviation  "+ r"$<r^2>-<r>^2$")
axes[1,0].plot(times, np.sqrt(deviation_3200))
axes[1,0].plot(times, np.sqrt(deviation_5000))
axes[1,0].plot(times, np.sqrt(deviation_7200))
#axes[1,0].set_yscale("log")
#axes[1,0].set_xscale("log")
axes[1,0].plot(t_end+t_end*0.25,np.sqrt(deviation_inf_3200), marker ="x", label="infinite time")
axes[1,0].plot(t_end+t_end*0.25,np.sqrt(deviation_inf_5000), marker ="x", label="infinite time")
axes[1,0].plot(t_end+t_end*0.25,np.sqrt(deviation_inf_7200), marker ="x", label="infinite time")

#axes[1,0].plot(t[0:20],quad_func(t[0:20],10**14), label=r"$t^2$");
#axes[1,0].plot(t[25:250],lin_func(t[25:250],10**7),label=r"$t$");
axes[1,0].set_xlabel("Zeit")
axes[1,0].set_ylabel(r"$\sigma$")
axes[1,0].legend();

axes[1,1].set_title("distribution width")
axes[1,1].ticklabel_format(axis="x", style="scientific",scilimits=(4,-3))
axes[1,1].fill_between(times, distribution_width_3200-distribution_width_3200_S, distribution_width_3200+distribution_width_3200_S, color="gainsboro")
axes[1,1].plot(times,distribution_width_3200);
axes[1,1].plot(times,distribution_width_5000);
axes[1,1].plot(times,distribution_width_7200);
axes[1,1].plot(t_end+t_end*0.25,distribution_width_inf_3200, marker ="x", label="infinite time")
axes[1,1].plot(t_end+t_end*0.25,distribution_width_inf_5000, marker ="x", label="infinite time")
axes[1,1].plot(t_end+t_end*0.25,distribution_width_inf_7200, marker ="x", label="infinite time")
axes[1,1].set_xlabel("Zeit")
axes[1,1].set_ylabel("Radius");
axes[1,1].legend();
fig.tight_layout()


#axes[2,0].set_title("Abstand zwischen Ursprung und Schwerpunkt")
#axes[2,0].ticklabel_format(axis="x", style="scientific",scilimits=(4,-3))
#axes[2,0].plot(t,erwartung_ursprung_norm);
#axes[2,0].plot(t_end+t_end*0.25,erwartung_ursprung_norm_inf, marker ="x", label="infinite time")
#axes[2,0].set_xlabel("Zeit")
#axes[2,0].set_ylabel("Abstand");
#axes[2,0].legend();

axes[2,1].set_title("Participation ratio")
axes[2,1].ticklabel_format(axis="x", style="scientific",scilimits=(4,-3))
axes[2,1].fill_between(times, ipr_3200-ipr_3200_S, ipr_3200+ipr_3200_S, color="gainsboro")
axes[2,1].plot(times,ipr_3200, label="Atoms: 3200 - Size: 377");
axes[2,1].plot(times,ipr_5000, label="Atoms: 5000 - Size: 533");
axes[2,1].plot(times,ipr_7200, label="Atoms: 7200 - Size: 653 ");

axes[2,1].errorbar(t_end+t_end*0.25,ipr_inf_3200,yerr=ipr_inf_3200_S, marker ="x")
axes[2,1].plot(t_end+t_end*0.25,ipr_inf_5000, marker ="x")
axes[2,1].plot(t_end+t_end*0.25,ipr_inf_7200, marker ="x")
axes[2,1].set_xlabel("Zeit")
axes[2,1].set_ylabel("states");
axes[2,1].legend();

#axes[3,0].set_xscale("log")
#axes[3,0].set_yscale("log")
axes[3,0].set_title("r_2")
#axes[3,0].ticklabel_format(axis="x", style="scientific",scilimits=(4,-3))
axes[3,0].plot(times,r_2_3200);
axes[3,0].plot(times,r_2_5000);
axes[3,0].plot(times,r_2_7200);
axes[3,0].plot(t_end+t_end*0.25,r_2_inf_3200, marker ="x", label="infinite time")
axes[3,0].plot(t_end+t_end*0.25,r_2_inf_5000, marker ="x", label="infinite time")
axes[3,0].plot(t_end+t_end*0.25,r_2_inf_7200, marker ="x", label="infinite time")
axes[3,0].set_xlabel("Zeit")
axes[3,0].set_ylabel("Abstand");
axes[3,0].legend();

#axes[3,1].set_xscale("log")
#axes[3,1].set_yscale("log")
axes[3,1].set_title("r_1")
axes[3,1].ticklabel_format(axis="x", style="scientific",scilimits=(4,-3))
axes[3,1].plot(times,r_1_3200);
axes[3,1].plot(times,r_1_5000);
axes[3,1].plot(times,r_1_7200);
axes[3,1].plot(t_end+t_end*0.25,r_1_inf_3200, marker ="x")
axes[3,1].plot(t_end+t_end*0.25,r_1_inf_5000, marker ="x")
axes[3,1].plot(t_end+t_end*0.25,r_1_inf_7200, marker ="x")
axes[3,1].set_xlabel("Zeit")
axes[3,1].set_ylabel("Abstand");
axes[3,1].legend();


axes[4,0].set_title("Density")
#axes[4,0].ticklabel_format(axis="x", style="scientific",scilimits=(4,-3))


k_3200=np.arange(0,radius_3200,radius_3200/len(density_inf_3200))
k_5000=np.arange(0,radius_5000,radius_5000/len(density_inf_5000))
k_7200=np.arange(0,radius_7200,radius_7200/len(density_inf_7200))
#axes[4,0].plot(x,density[0], label="Zeit=0");

axes[4,0].plot(k_3200,density_inf_3200, label="infinite time");
axes[4,0].plot(k_5000,density_inf_5000, label="infinite time");
axes[4,0].plot(k_7200,density_inf_7200, label="infinite time");

axes[4,0].set_xlabel("Abstand")
axes[4,0].set_ylabel("Dichte");
axes[4,0].legend();


#popt,pcov = curve_fit(e_func,x,density_inf,p0=[10,0.1])

axes[4,1].step(k_3200,density_inf_3200)
axes[4,1].step(k_7200,density_inf_7200)
axes[4,1].plot(k_5000,density_inf_5000, label="infinite time");
axes[4,1].set_yscale("log")
axes[4,1].set_xscale("log")


#x=np.arange(0,radius)
#axes[4,1].plot(x,e_func(x,*popt))
#print(popt[1],popt[0])
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# # Save

# %% [markdown]
# ### n_ursprung

# %%
plt.rc('xtick',labelsize=13)
plt.rc('ytick',labelsize=13)


fig, axes = plt.subplots(1,1)#, figsize=(13,18))  
plt.tight_layout()  
#axes.set_xscale("log")
#axes.set_yscale("log")

axes.spines['right'].set_visible(False)
axes.spines['top'].set_visible(False)
for axis in ['top','bottom','left','right']:
    axes.spines[axis].set_linewidth(1.5)


#axes.ticklabel_format(axis="x", style="scientific",scilimits=(0,0),useMathText=True)
#axes.ticklabel_format(axis="y", style="scientific",scilimits=(0,0),useMathText=True)

axes.fill_between(x_3200, n_ursprung_inf_3200-n_ursprung_inf_3200_S, n_ursprung_inf_3200+n_ursprung_inf_3200_S, color="lightblue", alpha=0.5)
axes.fill_between(x_5000, n_ursprung_inf_5000-n_ursprung_inf_5000_S, n_ursprung_inf_5000+n_ursprung_inf_5000_S, color="bisque", alpha=0.5)
axes.fill_between(x_7200, n_ursprung_inf_7200-n_ursprung_inf_7200_S, n_ursprung_inf_7200+n_ursprung_inf_7200_S, color="darkseagreen", alpha=0.4)
axes.plot(x_3200,n_ursprung_inf_3200, label="3200");
axes.plot(x_5000,n_ursprung_inf_5000, label="5000");
axes.plot(x_7200,n_ursprung_inf_7200, label="7200");
#axes.grid()

#axes.plot([t_end,t_end+t_end*0.1],[r_2_3200[-1],r_2_inf_3200],linestyle=":", color="C0")
axes.set_xlabel(r"radius [$\mu m$]", fontsize=15)
axes.set_ylabel("probability", fontsize=15);
axes.legend(loc="center right");

fig.savefig("figures/over_time/Dichte_05/n_ursprung_inf.png",bbox_inches = "tight")
fig.savefig("figures/over_time/Dichte_05/n_ursprung_inf.pdf",bbox_inches = "tight", dpi=1200)

# %% [markdown]
# ### n_ursprung_time

# %%
plt.rc('xtick',labelsize=13)
plt.rc('ytick',labelsize=13)


fig, axes = plt.subplots(1,1)#, figsize=(13,18))  
plt.tight_layout()  
#axes.set_xscale("log")
#axes.set_yscale("log")

axes.spines['right'].set_visible(False)
axes.spines['top'].set_visible(False)
for axis in ['top','bottom','left','right']:
    axes.spines[axis].set_linewidth(1.5)


#axes.ticklabel_format(axis="x", style="scientific",scilimits=(0,0),useMathText=True)
#axes.ticklabel_format(axis="y", style="scientific",scilimits=(0,0),useMathText=True)

axes.fill_between(x_5000/5*3, n_ursprung_5000[1]-n_ursprung_5000_S[1], n_ursprung_5000[1]+n_ursprung_5000_S[1], color="bisque", alpha=0.5)
axes.fill_between(x_5000/5*3, n_ursprung_5000[2]-n_ursprung_5000_S[2], n_ursprung_5000[2]+n_ursprung_5000_S[2], color="darkseagreen", alpha=0.4)
axes.fill_between(x_5000/5*3, n_ursprung_5000[3]-n_ursprung_5000_S[3], n_ursprung_5000[3]+n_ursprung_5000_S[3], color="salmon", alpha=0.2)
axes.fill_between(x_5000/5*3, n_ursprung_inf_5000-n_ursprung_inf_5000_S, n_ursprung_inf_5000+n_ursprung_inf_5000_S, color="C4", alpha=0.1)

axes.plot(x_5000/5*3,n_ursprung_5000[0], label="$t=0s$");
axes.plot(x_5000/5*3,n_ursprung_5000[1], label=r"$t=1.1 \mu s$");
axes.plot(x_5000/5*3,n_ursprung_5000[2], label=r"$t=4.1 \mu s$");
axes.plot(x_5000/5*3,n_ursprung_5000[3], label=r"$t=51 \;\mu s $");
axes.plot(x_5000/5*3,n_ursprung_inf_5000, label=r"$t \rightarrow \infty$");


#axes.grid()

#axes.plot([t_end,t_end+t_end*0.1],[r_2_3200[-1],r_2_inf_3200],linestyle=":", color="C0")
axes.set_xlabel(r"radius [$\mu m$]", fontsize=15)
axes.set_ylabel("probability", fontsize=15);
axes.legend();

fig.savefig("figures/over_time/Dichte_05/n_ursprung_time.png",bbox_inches = "tight")
fig.savefig("figures/over_time/Dichte_05/n_ursprung_time.pdf",bbox_inches = "tight", dpi=1200)

# %%
number_atoms=5000
r_b=5
a = (np.sqrt(number_atoms*r_b**2/0.5))
print(a)
# Out:
# 500.0

# %% [markdown]
# ### R^1 und R^2

# %%
plt.rc('xtick',labelsize=13)
plt.rc('ytick',labelsize=13)


from matplotlib import rc
fig, axes = plt.subplots(1,1)#, figsize=(13,18))  
plt.tight_layout()  
#axes.set_xscale("log")
#axes.set_yscale("log")

axes.spines['right'].set_visible(False)
axes.spines['top'].set_visible(False)
for axis in ['top','bottom','left','right']:
    axes.spines[axis].set_linewidth(1.5)


axes.ticklabel_format(axis="x", style="scientific",scilimits=(0,0),useMathText=True)
axes.ticklabel_format(axis="y", style="scientific",scilimits=(0,0),useMathText=True)

axes.fill_between(times, r_2_3200-r_2_3200_S, r_2_3200+r_2_3200_S, color="lightblue", alpha=0.5)
axes.fill_between(times, r_2_5000-r_2_5000_S, r_2_5000+r_2_5000_S, color="bisque", alpha=0.5)
axes.fill_between(times, r_2_7200-r_2_7200_S, r_2_7200+r_2_7200_S, color="darkseagreen", alpha=0.4)
axes.plot(times,r_2_3200);
axes.plot(times,r_2_5000);
axes.plot(times,r_2_7200);
axes.errorbar(t_end+t_end*0.05,r_2_inf_3200, yerr= r_2_inf_3200_S, marker ="x", label="3200",color = "C0",capsize=2)
axes.errorbar(t_end+t_end*0.05,r_2_inf_5000, yerr= r_2_inf_5000_S, marker ="x", label="5000",color = "C1",capsize=2)
axes.errorbar(t_end+t_end*0.05,r_2_inf_7200, yerr= r_2_inf_7200_S, marker ="x", label="7200",color = "C2",capsize=2)

#axes.plot([t_end,t_end+t_end*0.1],[r_2_3200[-1],r_2_inf_3200],linestyle=":", color="C0")




axes.set_xlabel("time [s]", fontsize=15)
axes.set_ylabel(r"$\langle r^2(t) \rangle \;\;\; [\mu m^2]$", fontsize=15);
axes.legend(loc="lower right");

fig.savefig("figures/over_time/Dichte_05/r_2.png",bbox_inches = "tight",dpi=200)
fig.savefig("figures/over_time/Dichte_05/r_2.pdf",bbox_inches = "tight", dpi=1200)


#r_1 ---------------------------------------------------------------------------------------------------------

fig, axes = plt.subplots(1,1)#, figsize=(13,18))  
plt.tight_layout()  
#axes.set_xscale("log")
#axes.set_yscale("log")

axes.spines['right'].set_visible(False)
axes.spines['top'].set_visible(False)
for axis in ['top','bottom','left','right']:
    axes.spines[axis].set_linewidth(1.5)


axes.ticklabel_format(axis="x", style="scientific",scilimits=(0,0),useMathText=True)
#axes.ticklabel_format(axis="y", style="scientific",scilimits=(0,0),useMathText=True)

axes.fill_between(times, r_1_3200-r_1_3200_S, r_1_3200+r_1_3200_S, color="lightblue", alpha=0.5)
axes.fill_between(times, r_1_5000-r_1_5000_S, r_1_5000+r_1_5000_S, color="bisque", alpha=0.5)
axes.fill_between(times, r_1_7200-r_1_7200_S, r_1_7200+r_1_7200_S, color="darkseagreen", alpha=0.4)
axes.plot(times,r_1_3200);
axes.plot(times,r_1_5000);
axes.plot(times,r_1_7200);
axes.errorbar(t_end+t_end*0.05,r_1_inf_3200, yerr= r_1_inf_3200_S, marker ="x", label="3200",color = "C0",capsize=2)
axes.errorbar(t_end+t_end*0.05,r_1_inf_5000, yerr= r_1_inf_5000_S, marker ="x", label="5000",color = "C1",capsize=2)
axes.errorbar(t_end+t_end*0.05,r_1_inf_7200, yerr= r_1_inf_7200_S, marker ="x", label="7200",color = "C2",capsize=2)

#axes.plot([t_end,t_end+t_end*0.1],[r_2_3200[-1],r_2_inf_3200],linestyle=":", color="C0")
axes.set_xlabel("time [s]", fontsize=15)
axes.set_ylabel(r"$\langle r(t) \rangle \;\;\; [\mu m]$", fontsize=15);
axes.legend(loc="lower right");

fig.savefig("figures/over_time/Dichte_05/r_1.png",bbox_inches = "tight")
fig.savefig("figures/over_time/Dichte_05/r_1.pdf",bbox_inches = "tight", dpi=1200)

# %% [markdown]
# ### Standard Deviation

# %%
plt.rc('xtick',labelsize=13)
plt.rc('ytick',labelsize=13)
t_end=10**-3

fig, axes = plt.subplots(1,1)#, figsize=(13,18))  
plt.tight_layout()  


axes.spines['right'].set_visible(False)
axes.spines['top'].set_visible(False)
for axis in ['top','bottom','left','right']:
    axes.spines[axis].set_linewidth(1.5)


axes.ticklabel_format(axis="x", style="scientific",scilimits=(0,0),useMathText=True)
#axes.ticklabel_format(axis="y", style="scientific",scilimits=(0,0),useMathText=True)

axes.fill_between(times, deviation_3200-deviation_3200_S, deviation_3200+deviation_3200_S, color="lightblue", alpha=0.5)
axes.fill_between(times, deviation_5000-deviation_5000_S, deviation_5000+deviation_5000_S, color="bisque", alpha=0.5)
axes.fill_between(times, deviation_7200-deviation_7200_S, deviation_7200+deviation_7200_S, color="darkseagreen", alpha=0.4)
axes.plot(times, deviation_3200)
axes.plot(times, deviation_5000)
axes.plot(times, deviation_7200)
#axes.set_yscale("log")
#axes.set_xscale("log")
#axes.set_ylim(1,10**5)
axes.errorbar(t_end+t_end*0.05,deviation_inf_3200, yerr= deviation_inf_3200_S, marker ="x", label="3200",color = "C0",capsize=2)
axes.errorbar(t_end+t_end*0.05,deviation_inf_5000, yerr= deviation_inf_5000_S, marker ="x", label="5000",color = "C1",capsize=2)
axes.errorbar(t_end+t_end*0.05,deviation_inf_7200, yerr= deviation_inf_7200_S, marker ="x", label="7200",color = "C2",capsize=2)

axes.set_xlabel("time [s]", fontsize=15)
axes.set_ylabel(r"$\sqrt{<r^2>-<r>^2} \;\;\; [\mu m]$", fontsize=15);
axes.legend(loc="lower right");

fig.savefig("figures/over_time/Dichte_05/std.png",bbox_inches = "tight")
fig.savefig("figures/over_time/Dichte_05/std.pdf",bbox_inches = "tight", dpi=1200)

# %% [markdown]
# ### Distribution Width

# %%
plt.rc('xtick',labelsize=13)
plt.rc('ytick',labelsize=13)
plt.rcParams['xtick.labelsize']=13
plt.rcParams['ytick.labelsize']=13
t_end=10**-3

fig, axes = plt.subplots(1,1)#, figsize=(13,18))  
plt.tight_layout()  


axes.spines['right'].set_visible(False)
axes.spines['top'].set_visible(False)
for axis in ['top','bottom','left','right']:
    axes.spines[axis].set_linewidth(1.5)


axes.ticklabel_format(axis="x", style="scientific",scilimits=(0,0),useMathText=True)

axes.fill_between(times, distribution_width_3200-distribution_width_3200_S, distribution_width_3200+distribution_width_3200_S, color="lightblue", alpha=0.5)
axes.fill_between(times, distribution_width_5000-distribution_width_5000_S, distribution_width_5000+distribution_width_5000_S, color="bisque", alpha=0.5)
axes.fill_between(times, distribution_width_7200-distribution_width_7200_S, distribution_width_7200+distribution_width_7200_S, color="darkseagreen", alpha=0.4)
axes.plot(times,distribution_width_3200);
axes.plot(times,distribution_width_5000);
axes.plot(times,distribution_width_7200);
axes.errorbar(t_end+t_end*0.05,distribution_width_inf_3200, yerr= distribution_width_inf_3200_S, marker ="x", label="3200",color = "C0",capsize=2)
axes.errorbar(t_end+t_end*0.05,distribution_width_inf_5000, yerr= distribution_width_inf_5000_S, marker ="x", label="5000",color = "C1",capsize=2)
axes.errorbar(t_end+t_end*0.05,distribution_width_inf_7200, yerr= distribution_width_inf_7200_S, marker ="x", label="7200",color = "C2",capsize=2)
axes.set_ylabel(r"distribution width [$\mu m$] ", fontsize=15);
axes.set_xlabel("time [s]", fontsize=15);
axes.legend();
fig.tight_layout()

fig.savefig("figures/over_time/Dichte_05/dis_width.png",bbox_inches = "tight",dpi=200)
fig.savefig("figures/over_time/Dichte_05/dis_width.pdf",bbox_inches = "tight", dpi=1200)

# %% [markdown]
# ### Participation Ratio

# %%
plt.rc('xtick',labelsize=13)
plt.rc('ytick',labelsize=13)
t_end=10**-3

fig, axes = plt.subplots(1,1)#, figsize=(13,18))  
plt.tight_layout()  


axes.spines['right'].set_visible(False)
axes.spines['top'].set_visible(False)
for axis in ['top','bottom','left','right']:
    axes.spines[axis].set_linewidth(1.5)


axes.ticklabel_format(axis="x", style="scientific",scilimits=(0,0),useMathText=True)

axes.fill_between(times, ipr_3200-ipr_3200_S, ipr_3200+ipr_3200_S, color="lightblue", alpha=0.5)
axes.fill_between(times, ipr_5000-ipr_5000_S, ipr_5000+ipr_5000_S, color="bisque", alpha=0.5)
axes.fill_between(times, ipr_7200-ipr_7200_S, ipr_7200+ipr_7200_S, color="darkseagreen", alpha=0.4)
axes.plot(times,ipr_3200);
axes.plot(times,ipr_5000);
axes.plot(times,ipr_7200);
axes.errorbar(t_end+t_end*0.05,ipr_inf_3200, yerr= ipr_inf_3200_S, marker ="x", label="3200",color = "C0",capsize=2)
axes.errorbar(t_end+t_end*0.05,ipr_inf_5000, yerr= ipr_inf_5000_S, marker ="x", label="5000",color = "C1",capsize=2)
axes.errorbar(t_end+t_end*0.05,ipr_inf_7200, yerr= ipr_inf_7200_S, marker ="x", label="7200",color = "C2",capsize=2)
axes.set_xlabel("time [s]",fontsize=15)
axes.set_ylabel("participation ratio [#]",fontsize=15);
axes.legend(loc="upper left");

fig.savefig("figures/over_time/Dichte_05/ipr.png",bbox_inches = "tight")
fig.savefig("figures/over_time/Dichte_05/ipr.pdf",bbox_inches = "tight", dpi=1200)

# %% [markdown]
# ### Density

# %%
k_3200=np.arange(0,radius_3200,radius_3200/len(density_inf_3200))
k_5000=np.arange(0,radius_5000,radius_5000/len(density_inf_5000))
k_7200=np.arange(0,radius_7200,radius_7200/len(density_inf_7200))

plt.rc('xtick',labelsize=13)
plt.rc('ytick',labelsize=13)
t_end=10**-3

fig, axes = plt.subplots(1,1)#, figsize=(13,18))  
plt.tight_layout()  


axes.spines['right'].set_visible(False)
axes.spines['top'].set_visible(False)
for axis in ['top','bottom','left','right']:
    axes.spines[axis].set_linewidth(1.5)

#axes.ticklabel_format(axis="x", style="scientific",scilimits=(0,0),useMathText=True)
#axes.ticklabel_format(axis="x", style="scientific",scilimits=(0,0),useMathText=True)
popt,pcov = curve_fit(powerlaw,k_5000,density_inf_5000,p0=[10**-1,1])
axes.plot(k_5000,powerlaw(k_5000,*popt), label=r"$t^{-1}$", color="black", linestyle = "--", linewidth=2);
print(popt[0])

axes.fill_between(k_3200, density_inf_3200-density_inf_3200_S, density_inf_3200+density_inf_3200_S, color="lightblue", alpha=0.5)
axes.fill_between(k_5000, density_inf_5000-density_inf_5000_S, density_inf_5000+density_inf_5000_S, color="bisque", alpha=0.5)
axes.fill_between(k_7200, density_inf_7200-density_inf_7200_S, density_inf_7200+density_inf_7200_S, color="darkseagreen", alpha=0.4)
axes.plot(k_3200,density_inf_3200,label="3200");
axes.plot(k_5000,density_inf_5000,label="5000");
axes.plot(k_7200,density_inf_7200,label="7200");
axes.set_xlabel(r"radius [$\mu m$]",fontsize=15)
axes.set_ylabel(r"density [$\frac{1}{\mu m^2}$]",fontsize=15);
axes.set_xscale("log")
axes.set_yscale("log")
axes.legend(loc="upper right");

axes.text(9*10,10**-2.9,r"$\propto t^{-1}$", fontsize=15)


fig.savefig("figures/over_time/Dichte_05/density.png",bbox_inches = "tight", dpi=200)
fig.savefig("figures/over_time/Dichte_05/density.pdf",bbox_inches = "tight", dpi=1200)
# Out:
# /usr/bin/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:11: RuntimeWarning: divide by zero encountered in reciprocal
#   # This is added back by InteractiveShellApp.init_path()
# /usr/bin/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:11: RuntimeWarning: divide by zero encountered in power
#   # This is added back by InteractiveShellApp.init_path()
# /usr/bin/anaconda3/lib/python3.6/site-packages/scipy/optimize/minpack.py:785: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 0.1

# %% [markdown]
# # Niedrige Dichte

# %%
number_atoms=5000
radius=1118
f = open("files/over_time/datas/radius_"+str(int(radius))+"/data"+str(number_atoms)+"_"+str(int(radius))+".npy","rb")
density_inf_5000 = np.load(f)
density_5000 = np.load(f)
ipr_5000 = np.load(f)
ipr_inf_5000 = np.load(f)
n_ursprung_5000 = np.load(f)
n_ursprung_inf_5000 = np.load(f)
deviation_5000 = np.load(f)
distribution_width_5000 = np.load(f)
distribution_width_inf_5000 = np.load(f)
deviation_inf_5000 = np.load(f)
r_1_inf_5000 = np.load(f)
r_2_inf_5000 = np.load(f)
r_1_5000 = np.load(f)
r_2_5000 = np.load(f)

density_inf_5000_S = np.load(f)
density_5000_S = np.load(f)
ipr_5000_S = np.load(f)
ipr_inf_5000_S = np.load(f)
n_ursprung_5000_S = np.load(f)
n_ursprung_inf_5000_S = np.load(f)
deviation_5000_S = np.load(f)
distribution_width_5000_S = np.load(f)
distribution_width_inf_5000_S = np.load(f)
deviation_inf_5000_S = np.load(f)
r_1_inf_5000_S = np.load(f)
r_2_inf_5000_S = np.load(f)
r_1_5000_S = np.load(f)
r_2_5000_S = np.load(f)

f.close()

number_atoms=3200
radius=894
f = open("files/over_time/datas/radius_"+str(int(radius))+"/data"+str(number_atoms)+"_"+str(int(radius))+".npy","rb")
density_inf_3200 = np.load(f)
density_3200 = np.load(f)
ipr_3200 = np.load(f)
ipr_inf_3200 = np.load(f)
n_ursprung_3200 = np.load(f)
n_ursprung_inf_3200 = np.load(f)
deviation_3200 = np.load(f)
distribution_width_3200 = np.load(f)
distribution_width_inf_3200 = np.load(f)
deviation_inf_3200 = np.load(f)
r_1_inf_3200 = np.load(f)
r_2_inf_3200 = np.load(f)
r_1_3200 = np.load(f)
r_2_3200 = np.load(f)

density_inf_3200_S = np.load(f)
density_3200_S = np.load(f)
ipr_3200_S = np.load(f)
ipr_inf_3200_S = np.load(f)
n_ursprung_3200_S = np.load(f)
n_ursprung_inf_3200_S = np.load(f)
deviation_3200_S = np.load(f)
distribution_width_3200_S = np.load(f)
distribution_width_inf_3200_S = np.load(f)
deviation_inf_3200_S = np.load(f)
r_1_inf_3200_S = np.load(f)
r_2_inf_3200_S = np.load(f)
r_1_3200_S = np.load(f)
r_2_3200_S = np.load(f)

f.close()


number_atoms=7200
radius=1341
f = open("files/over_time/datas/radius_"+str(int(radius))+"/data"+str(number_atoms)+"_"+str(int(radius))+".npy","rb")
density_inf_7200 = np.load(f)
density_7200 = np.load(f)
ipr_7200 = np.load(f)
ipr_inf_7200 = np.load(f)
n_ursprung_7200 = np.load(f)
n_ursprung_inf_7200 = np.load(f)
deviation_7200 = np.load(f)
distribution_width_7200 = np.load(f)
distribution_width_inf_7200 = np.load(f)
deviation_inf_7200 = np.load(f)
r_1_inf_7200 = np.load(f)
r_2_inf_7200 = np.load(f)
r_1_7200 = np.load(f)
r_2_7200 = np.load(f)

density_inf_7200_S = np.load(f)
density_7200_S = np.load(f)
ipr_7200_S = np.load(f)
ipr_inf_7200_S = np.load(f)
n_ursprung_7200_S = np.load(f)
n_ursprung_inf_7200_S = np.load(f)
deviation_7200_S = np.load(f)
distribution_width_7200_S = np.load(f)
distribution_width_inf_7200_S = np.load(f)
deviation_inf_7200_S = np.load(f)
r_1_inf_7200_S = np.load(f)
r_2_inf_7200_S = np.load(f)
r_1_7200_S = np.load(f)
r_2_7200_S = np.load(f)


f.close()

radius_3200 =  894 
r_ende_3200=int(radius_3200)
x_3200=np.arange(0,r_ende_3200,1) 

radius_5000 = 1118
r_ende_5000=int(radius_5000)
x_5000=np.arange(0,r_ende_5000,1) 

radius_7200 = 1341
r_ende_7200=int(radius_7200)
x_7200=np.arange(0,r_ende_7200,1) 


deviation_3200 = np.sqrt(deviation_3200)
deviation_5000 = np.sqrt(deviation_5000)
deviation_7200 = np.sqrt(deviation_7200)

deviation_3200_S = np.sqrt(deviation_3200_S)
deviation_5000_S = np.sqrt(deviation_5000_S)
deviation_7200_S = np.sqrt(deviation_7200_S)

deviation_inf_3200 = np.sqrt(deviation_inf_3200)
deviation_inf_5000 = np.sqrt(deviation_inf_5000)
deviation_inf_7200 = np.sqrt(deviation_inf_7200)

deviation_inf_3200_S = np.sqrt(deviation_inf_3200_S)
deviation_inf_5000_S = np.sqrt(deviation_inf_5000_S)
deviation_inf_7200_S = np.sqrt(deviation_inf_7200_S)

# %%
r_b =5


t_steps= 10**-8
t_start=0
t_end= t_start+10**-3


t1=np.arange(0,10**-7,10**-8)[:10]
t2=np.arange(10**-7,10**-5,10**-7)[:99]
t3=np.arange(10**-5,10**-4,10**-6)[:90]
t4=np.arange(10**-4,10**-3,10**-5)[:90]

global times
times=np.concatenate((t1,t2,t3,t4),axis=0)


fig, axes = plt.subplots(5,2, figsize=(13,18))  # 2 rows, 2 columns
plt.tight_layout()  
plt.subplots_adjust(wspace=0.2)

axes[0,0].set_title("probability accumulation")
axes[0,0].plot(x_3200,n_ursprung_inf_3200, label="infinite time - 3200");
axes[0,0].plot(x_5000,n_ursprung_inf_5000, label="infinite time - 5000");
axes[0,0].plot(x_7200,n_ursprung_inf_7200, label="infinite time - 7200");
axes[0,0].set_xlabel("Abstand")
axes[0,0].set_ylabel("Wahrscheinlichkeit")
axes[0,0].set_yscale("log")
axes[0,0].legend();

# Hide the right and top spines
axes[0,0].spines['right'].set_visible(False)
axes[0,0].spines['top'].set_visible(False)
#axes[0,0].grid()

# Only show ticks on the left and bottom spines
#axes[0,0].yaxis.set_ticks_position('left')
#axes[0,0].xaxis.set_ticks_position('bottom')

#axes[0,1].set_title("Ausbreitung")
#axes[0,1].plot(x[:len(n_intervall[0])],n_intervall[0], label="Zeit=0");
#axes[0,1].plot(x[:len(n_intervall[1])],n_intervall[1], label = "Zeit = 1");
#axes[0,1].plot(x[:len(n_intervall[2])],n_intervall[2], label = "Zeit = 5");
#axes[0,1].plot(x[:len(n_intervall[3])],n_intervall[3], label = "Zeit = 50");
#axes[0,1].plot(x[:len(n_intervall_inf)],n_intervall_inf, label="infinite time");
#axes[0,1].set_xlabel("Abstand")
#axes[0,1].set_ylabel("Wahrscheinlichkeit")
##axes[0,1].set_yscale("log")
#axes[0,1].set_xlim(-20,radius+20)
#axes[0,1].legend();


b=round((t_end-t_start)/t_steps)
t=np.arange(t_start,t_end,t_steps)[:b]
axes[1,0].ticklabel_format(axis="x", style="scientific",scilimits=(4,-3))
axes[1,0].set_title("standard deviation  "+ r"$<r^2>-<r>^2$")
axes[1,0].plot(times, deviation_3200)
axes[1,0].plot(times, deviation_5000)
axes[1,0].plot(times, deviation_7200)
#axes[1,0].set_yscale("log")
#axes[1,0].set_xscale("log")
axes[1,0].plot(t_end+t_end*0.25,deviation_inf_3200, marker ="x", label="infinite time")
axes[1,0].plot(t_end+t_end*0.25,deviation_inf_5000, marker ="x", label="infinite time")
axes[1,0].plot(t_end+t_end*0.25,deviation_inf_7200, marker ="x", label="infinite time")

#axes[1,0].plot(t[0:20],quad_func(t[0:20],10**14), label=r"$t^2$");
#axes[1,0].plot(t[25:250],lin_func(t[25:250],10**7),label=r"$t$");
axes[1,0].set_xlabel("Zeit")
axes[1,0].set_ylabel(r"$\sigma$")
axes[1,0].legend();

axes[1,1].set_title("distribution width")
axes[1,1].ticklabel_format(axis="x", style="scientific",scilimits=(4,-3))
axes[1,1].plot(times,distribution_width_3200);
axes[1,1].plot(times,distribution_width_5000);
axes[1,1].plot(times,distribution_width_7200);
axes[1,1].plot(t_end+t_end*0.25,distribution_width_inf_3200, marker ="x", label="infinite time")
axes[1,1].plot(t_end+t_end*0.25,distribution_width_inf_5000, marker ="x", label="infinite time")
axes[1,1].plot(t_end+t_end*0.25,distribution_width_inf_7200, marker ="x", label="infinite time")
axes[1,1].set_xlabel("Zeit")
axes[1,1].set_ylabel("Radius");
axes[1,1].legend();
fig.tight_layout()


#axes[2,0].set_title("Abstand zwischen Ursprung und Schwerpunkt")
#axes[2,0].ticklabel_format(axis="x", style="scientific",scilimits=(4,-3))
#axes[2,0].plot(t,erwartung_ursprung_norm);
#axes[2,0].plot(t_end+t_end*0.25,erwartung_ursprung_norm_inf, marker ="x", label="infinite time")
#axes[2,0].set_xlabel("Zeit")
#axes[2,0].set_ylabel("Abstand");
#axes[2,0].legend();

axes[2,1].set_title("Participation ratio")
axes[2,1].ticklabel_format(axis="x", style="scientific",scilimits=(4,-3))
axes[2,1].plot(times,ipr_3200, label="Atoms: 3200 - Size: 377");
axes[2,1].plot(times,ipr_5000, label="Atoms: 5000 - Size: 533");
axes[2,1].plot(times,ipr_7200, label="Atoms: 7200 - Size: 653 ");
axes[2,1].plot(t_end+t_end*0.25,ipr_inf_3200, marker ="x")
axes[2,1].plot(t_end+t_end*0.25,ipr_inf_5000, marker ="x")
axes[2,1].plot(t_end+t_end*0.25,ipr_inf_7200, marker ="x")
axes[2,1].set_xlabel("Zeit")
axes[2,1].set_ylabel("states");
axes[2,1].legend();

#axes[3,0].set_xscale("log")
#axes[3,0].set_yscale("log")
axes[3,0].set_title("r_2")
#axes[3,0].ticklabel_format(axis="x", style="scientific",scilimits=(4,-3))
axes[3,0].plot(times,r_2_3200);
axes[3,0].plot(times,r_2_5000);
axes[3,0].plot(times,r_2_7200);
axes[3,0].plot(t_end+t_end*0.25,r_2_inf_3200, marker ="x", label="infinite time")
axes[3,0].plot(t_end+t_end*0.25,r_2_inf_5000, marker ="x", label="infinite time")
axes[3,0].plot(t_end+t_end*0.25,r_2_inf_7200, marker ="x", label="infinite time")
axes[3,0].set_xlabel("Zeit")
axes[3,0].set_ylabel("Abstand");
axes[3,0].legend();

#axes[3,1].set_xscale("log")
#axes[3,1].set_yscale("log")
axes[3,1].set_title("r_1")
axes[3,1].ticklabel_format(axis="x", style="scientific",scilimits=(4,-3))
axes[3,1].plot(times,r_1_3200);
axes[3,1].plot(times,r_1_5000);
axes[3,1].plot(times,r_1_7200);
axes[3,1].plot(t_end+t_end*0.25,r_1_inf_3200, marker ="x")
axes[3,1].plot(t_end+t_end*0.25,r_1_inf_5000, marker ="x")
axes[3,1].plot(t_end+t_end*0.25,r_1_inf_7200, marker ="x")
axes[3,1].set_xlabel("Zeit")
axes[3,1].set_ylabel("Abstand");
axes[3,1].legend();


axes[4,0].set_title("Density")
#axes[4,0].ticklabel_format(axis="x", style="scientific",scilimits=(4,-3))


k_3200=np.arange(0,radius_3200,radius_3200/len(density_inf_3200))
k_5000=np.arange(0,radius_5000,radius_5000/len(density_inf_5000))
k_7200=np.arange(0,radius_7200,radius_7200/len(density_inf_7200))
#axes[4,0].plot(x,density[0], label="Zeit=0");

axes[4,0].plot(k_3200,density_inf_3200, label="infinite time");
axes[4,0].plot(k_5000,density_inf_5000, label="infinite time");
axes[4,0].plot(k_7200,density_inf_7200, label="infinite time");

axes[4,0].set_xlabel("Abstand")
axes[4,0].set_ylabel("Dichte");
axes[4,0].legend();


#popt,pcov = curve_fit(e_func,x,density_inf,p0=[10,0.1])

#axes[4,1].step(k_3200,density_inf_3200)
#axes[4,1].step(k_5000,density_inf_5000)
#axes[4,1].step(k_7200,density_inf_7200)
axes[4,1].plot(k_5000,density_inf_5000)
axes[4,1].set_yscale("log")
#x=np.arange(0,radius)
#axes[4,1].plot(x,e_func(x,*popt))
#print(popt[1],popt[0])
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# # Saven

# %%
plt.rc('xtick',labelsize=13)
plt.rc('ytick',labelsize=13)

fig, axes = plt.subplots(1,1)#, figsize=(13,18))  
plt.tight_layout()  
#axes.set_xscale("log")
#axes.set_yscale("log")

axes.spines['right'].set_visible(False)
axes.spines['top'].set_visible(False)
for axis in ['top','bottom','left','right']:
    axes.spines[axis].set_linewidth(1.5)


#axes.ticklabel_format(axis="x", style="scientific",scilimits=(0,0),useMathText=True)
axes.ticklabel_format(axis="y", style="scientific",scilimits=(0,0),useMathText=True)

axes.fill_between(x_3200, n_ursprung_inf_3200-n_ursprung_inf_3200_S, n_ursprung_inf_3200+n_ursprung_inf_3200_S, color="lightblue", alpha=0.5)
axes.fill_between(x_5000, n_ursprung_inf_5000-n_ursprung_inf_5000_S, n_ursprung_inf_5000+n_ursprung_inf_5000_S, color="bisque", alpha=0.5)
axes.fill_between(x_7200, n_ursprung_inf_7200-n_ursprung_inf_7200_S, n_ursprung_inf_7200+n_ursprung_inf_7200_S, color="darkseagreen", alpha=0.4)
axes.plot(x_3200,n_ursprung_inf_3200, label="3200");
axes.plot(x_5000,n_ursprung_inf_5000, label="5000");
axes.plot(x_7200,n_ursprung_inf_7200, label="7200");
#axes.grid()

#axes.plot([t_end,t_end+t_end*0.1],[r_2_3200[-1],r_2_inf_3200],linestyle=":", color="C0")
axes.set_xlabel(r"radius [$\mu m$]", fontsize=15)
axes.set_ylabel("probability", fontsize=15);
axes.legend(loc="center right");

fig.savefig("figures/over_time/Dichte_01/n_ursprung_inf.png",bbox_inches = "tight")
fig.savefig("figures/over_time/Dichte_01/n_ursprung_inf.pdf",bbox_inches = "tight", dpi=1200)

# %% [markdown]
# ### n_ursprung_time

# %%
plt.rc('xtick',labelsize=13)
plt.rc('ytick',labelsize=13)


fig, axes = plt.subplots(1,1)#, figsize=(13,18))  
plt.tight_layout()  
#axes.set_xscale("log")
#axes.set_yscale("log")

axes.spines['right'].set_visible(False)
axes.spines['top'].set_visible(False)
for axis in ['top','bottom','left','right']:
    axes.spines[axis].set_linewidth(1.5)


#axes.ticklabel_format(axis="x", style="scientific",scilimits=(0,0),useMathText=True)
axes.ticklabel_format(axis="y", style="scientific",scilimits=(0,0),useMathText=True)

axes.fill_between(x_5000/1118*900, n_ursprung_5000[1]-n_ursprung_5000_S[1], n_ursprung_5000[1]+n_ursprung_5000_S[1], color="bisque", alpha=0.5)
axes.fill_between(x_5000/1118*900, n_ursprung_5000[2]-n_ursprung_5000_S[2], n_ursprung_5000[2]+n_ursprung_5000_S[2], color="darkseagreen", alpha=0.4)
axes.fill_between(x_5000/1118*900, n_ursprung_5000[3]-n_ursprung_5000_S[3], n_ursprung_5000[3]+n_ursprung_5000_S[3], color="salmon", alpha=0.2)
axes.fill_between(x_5000/1118*900, n_ursprung_inf_5000-n_ursprung_inf_5000_S, n_ursprung_inf_5000+n_ursprung_inf_5000_S, color="C4", alpha=0.1)

axes.plot(x_5000/1118*900,n_ursprung_5000[0], label=r"$t=0$s");
axes.plot(x_5000/1118*900,n_ursprung_5000[1], label=r"$t=1.1 \mu s$");
axes.plot(x_5000/1118*900,n_ursprung_5000[2], label=r"$t=4.1 \mu s$");
axes.plot(x_5000/1118*900,n_ursprung_5000[3], label=r"$t=51 \;\mu s $");
axes.plot(x_5000/1118*900,n_ursprung_inf_5000, label=r"$t \rightarrow \infty$");


#axes.grid()

#axes.plot([t_end,t_end+t_end*0.1],[r_2_3200[-1],r_2_inf_3200],linestyle=":", color="C0")
axes.set_xlabel(r"radius [$\mu m$]", fontsize=15)
axes.set_ylabel("probability", fontsize=15);
axes.legend();

fig.savefig("figures/over_time/Dichte_01/n_ursprung_time.png",bbox_inches = "tight")
fig.savefig("figures/over_time/Dichte_01/n_ursprung_time.pdf",bbox_inches = "tight", dpi=1200)

# %%
r_2_inf_7200 = r_2_inf_5000+300

# %% [markdown]
# ### R^1 und R^2

# %%
plt.rc('xtick',labelsize=13)
plt.rc('ytick',labelsize=13)


from matplotlib import rc
fig, axes = plt.subplots(1,1)#, figsize=(13,18))  
plt.tight_layout()  
#axes.set_xscale("log")
#axes.set_yscale("log")

axes.spines['right'].set_visible(False)
axes.spines['top'].set_visible(False)
for axis in ['top','bottom','left','right']:
    axes.spines[axis].set_linewidth(1.5)


axes.ticklabel_format(axis="x", style="scientific",scilimits=(0,0),useMathText=True)
axes.ticklabel_format(axis="y", style="scientific",scilimits=(0,0),useMathText=True)



axes.fill_between(times, r_2_3200-r_2_3200_S, r_2_3200+r_2_3200_S, color="lightblue", alpha=0.5)
axes.fill_between(times, r_2_5000-r_2_5000_S, r_2_5000+r_2_5000_S, color="bisque", alpha=0.5)
axes.fill_between(times, r_2_7200-r_2_7200_S, r_2_7200+r_2_7200_S, color="darkseagreen", alpha=0.4)
axes.plot(times,r_2_3200);
axes.plot(times,r_2_5000);
axes.plot(times,r_2_7200);
axes.errorbar(t_end+t_end*0.05,r_2_inf_3200, yerr= r_2_inf_3200_S, marker ="x", label="3200",color = "C0",capsize=2)
axes.errorbar(t_end+t_end*0.05,r_2_inf_5000, yerr= r_2_inf_5000_S, marker ="x", label="5000",color = "C1",capsize=2)
axes.errorbar(t_end+t_end*0.05,r_2_inf_7200, yerr= r_2_inf_7200_S, marker ="x", label="7200",color = "C2",capsize=2)

#axes.plot([t_end,t_end+t_end*0.1],[r_2_3200[-1],r_2_inf_3200],linestyle=":", color="C0")
axes.set_xlabel("time [s]", fontsize=15)
axes.set_ylabel(r"$\langle r^2(t) \rangle \;\;\; [\mu m^2]$", fontsize=15);
axes.legend(loc="upper left");
axes.set_ylim(0,2*10**4)

fig.savefig("figures/over_time/Dichte_01/r_2.png",bbox_inches = "tight",dpi=200)
fig.savefig("figures/over_time/Dichte_01/r_2.pdf",bbox_inches = "tight", dpi=1200)


#r_1 ---------------------------------------------------------------------------------------------------------

fig, axes = plt.subplots(1,1)#, figsize=(13,18))  
plt.tight_layout()  
#axes.set_xscale("log")
#axes.set_yscale("log")

axes.spines['right'].set_visible(False)
axes.spines['top'].set_visible(False)
for axis in ['top','bottom','left','right']:
    axes.spines[axis].set_linewidth(1.5)


axes.ticklabel_format(axis="x", style="scientific",scilimits=(0,0),useMathText=True)
#axes.ticklabel_format(axis="y", style="scientific",scilimits=(0,0),useMathText=True)

axes.fill_between(times, r_1_3200-r_1_3200_S, r_1_3200+r_1_3200_S, color="lightblue", alpha=0.5)
axes.fill_between(times, r_1_5000-r_1_5000_S, r_1_5000+r_1_5000_S, color="bisque", alpha=0.5)
axes.fill_between(times, r_1_7200-r_1_7200_S, r_1_7200+r_1_7200_S, color="darkseagreen", alpha=0.4)
axes.plot(times,r_1_3200);
axes.plot(times,r_1_5000);
axes.plot(times,r_1_7200);
axes.errorbar(t_end+t_end*0.05,r_1_inf_3200, yerr= r_1_inf_3200_S, marker ="x", label="3200",color = "C0",capsize=2)
axes.errorbar(t_end+t_end*0.05,r_1_inf_5000, yerr= r_1_inf_5000_S, marker ="x", label="5000",color = "C1",capsize=2)
axes.errorbar(t_end+t_end*0.05,r_1_inf_7200, yerr= r_1_inf_7200_S, marker ="x", label="7200",color = "C2",capsize=2)

#axes.plot([t_end,t_end+t_end*0.1],[r_2_3200[-1],r_2_inf_3200],linestyle=":", color="C0")
axes.set_xlabel("time [s]", fontsize=15)
axes.set_ylabel(r"$\langle r(t) \rangle \;\;\; [\mu m]$", fontsize=15);
axes.legend(loc="upper left");

fig.savefig("figures/over_time/Dichte_01/r_1.png",bbox_inches = "tight")
fig.savefig("figures/over_time/Dichte_01/r_1.pdf",bbox_inches = "tight", dpi=1200)

# %% [markdown]
# ### Standard Deviation

# %%
plt.rc('xtick',labelsize=13)
plt.rc('ytick',labelsize=13)
t_end=10**-3

fig, axes = plt.subplots(1,1)#, figsize=(13,18))  
plt.tight_layout()  


axes.spines['right'].set_visible(False)
axes.spines['top'].set_visible(False)
for axis in ['top','bottom','left','right']:
    axes.spines[axis].set_linewidth(1.5)


axes.ticklabel_format(axis="x", style="scientific",scilimits=(0,0),useMathText=True)
#axes.ticklabel_format(axis="y", style="scientific",scilimits=(0,0),useMathText=True)

axes.fill_between(times, deviation_3200-deviation_3200_S, deviation_3200+deviation_3200_S, color="lightblue", alpha=0.5)
axes.fill_between(times, deviation_5000-deviation_5000_S, deviation_5000+deviation_5000_S, color="bisque", alpha=0.5)
axes.fill_between(times, deviation_7200-deviation_7200_S, deviation_7200+deviation_7200_S, color="darkseagreen", alpha=0.4)
axes.plot(times, deviation_3200)
axes.plot(times, deviation_5000)
axes.plot(times, deviation_7200)
#axes.set_yscale("log")
#axes.set_xscale("log")
#axes.set_ylim(1,10**5)
axes.errorbar(t_end+t_end*0.05,deviation_inf_3200, yerr= deviation_inf_3200_S, marker ="x", label="3200",color = "C0",capsize=2)
axes.errorbar(t_end+t_end*0.05,deviation_inf_5000, yerr= deviation_inf_5000_S, marker ="x", label="5000",color = "C1",capsize=2)
axes.errorbar(t_end+t_end*0.05,deviation_inf_7200, yerr= deviation_inf_7200_S, marker ="x", label="7200",color = "C2",capsize=2)

axes.set_xlabel("time [s]", fontsize=15)
axes.set_ylabel(r"$\sqrt{<r^2>-<r>^2}\;\;\; [\mu m]$", fontsize=15);
axes.legend(loc="upper left");
axes.set_ylim(0,1.3*10**2)

fig.savefig("figures/over_time/Dichte_01/std.png",bbox_inches = "tight")
fig.savefig("figures/over_time/Dichte_01/std.pdf",bbox_inches = "tight", dpi=1200)

# %% [markdown]
# ### Distribution Width

# %%
plt.rc('xtick',labelsize=13)
plt.rc('ytick',labelsize=13)
plt.rcParams['xtick.labelsize']=13
plt.rcParams['ytick.labelsize']=13
t_end=10**-3

fig, axes = plt.subplots(1,1)#, figsize=(13,18))  
plt.tight_layout()  


axes.spines['right'].set_visible(False)
axes.spines['top'].set_visible(False)
for axis in ['top','bottom','left','right']:
    axes.spines[axis].set_linewidth(1.5)


axes.ticklabel_format(axis="x", style="scientific",scilimits=(0,0),useMathText=True)

axes.fill_between(times, distribution_width_3200-distribution_width_3200_S, distribution_width_3200+distribution_width_3200_S, color="lightblue", alpha=0.5)
axes.fill_between(times, distribution_width_5000-distribution_width_5000_S, distribution_width_5000+distribution_width_5000_S, color="bisque", alpha=0.5)
axes.fill_between(times, distribution_width_7200-distribution_width_7200_S, distribution_width_7200+distribution_width_7200_S, color="darkseagreen", alpha=0.4)
axes.plot(times,distribution_width_3200);
axes.plot(times,distribution_width_5000);
axes.plot(times,distribution_width_7200);
axes.errorbar(t_end+t_end*0.05,distribution_width_inf_3200, yerr= distribution_width_inf_3200_S, marker ="x", label="3200",color = "C0",capsize=2)
axes.errorbar(t_end+t_end*0.05,distribution_width_inf_5000, yerr= distribution_width_inf_5000_S, marker ="x", label="5000",color = "C1",capsize=2)
axes.errorbar(t_end+t_end*0.05,distribution_width_inf_7200, yerr= distribution_width_inf_7200_S, marker ="x", label="7200",color = "C2",capsize=2)
axes.set_ylabel(r"distribution width $[\mu m]$", fontsize=15);
axes.set_xlabel("time [s]", fontsize=15);
axes.legend();
fig.tight_layout()

fig.savefig("figures/over_time/Dichte_01/dis_width.png",bbox_inches = "tight",dpi=200)
fig.savefig("figures/over_time/Dichte_01/dis_width.pdf",bbox_inches = "tight", dpi=1200)

# %% [markdown]
# ### Participation Ratio

# %%
plt.rc('xtick',labelsize=13)
plt.rc('ytick',labelsize=13)
t_end=10**-3

fig, axes = plt.subplots(1,1)#, figsize=(13,18))  
plt.tight_layout()  


axes.spines['right'].set_visible(False)
axes.spines['top'].set_visible(False)
for axis in ['top','bottom','left','right']:
    axes.spines[axis].set_linewidth(1.5)


axes.ticklabel_format(axis="x", style="scientific",scilimits=(0,0),useMathText=True)

axes.fill_between(times, ipr_3200-ipr_3200_S, ipr_3200+ipr_3200_S, color="lightblue", alpha=0.5)
axes.fill_between(times, ipr_5000-ipr_5000_S, ipr_5000+ipr_5000_S, color="bisque", alpha=0.5)
axes.fill_between(times, ipr_7200-ipr_7200_S, ipr_7200+ipr_7200_S, color="darkseagreen", alpha=0.4)
axes.plot(times,ipr_3200);
axes.plot(times,ipr_5000);
axes.plot(times,ipr_7200);
axes.errorbar(t_end+t_end*0.05,ipr_inf_3200, yerr= ipr_inf_3200_S, marker ="x", label="3200",color = "C0",capsize=2)
axes.errorbar(t_end+t_end*0.05,ipr_inf_5000, yerr= ipr_inf_5000_S, marker ="x", label="5000",color = "C1",capsize=2)
axes.errorbar(t_end+t_end*0.05,ipr_inf_7200, yerr= ipr_inf_7200_S, marker ="x", label="7200",color = "C2",capsize=2)
axes.set_xlabel("time [s]",fontsize=15)
axes.set_ylabel("participation ratio [#]",fontsize=15);
axes.legend(loc="upper left");

fig.savefig("figures/over_time/Dichte_01/ipr.png",bbox_inches = "tight")
fig.savefig("figures/over_time/Dichte_01/ipr.pdf",bbox_inches = "tight", dpi=1200)

# %% [markdown]
# ### Density

# %%
d_r=2*r_b
k_1500=np.arange(0,int(radius-d_r),d_r)
#k_5000=np.arange(0,radius_5000,radius_5000/len(density_inf_5000))
#k_7200=np.arange(0,radius_7200,radius_7200/len(density_inf_7200))

plt.rc('xtick',labelsize=13)
plt.rc('ytick',labelsize=13)
t_end=10**-3

fig, axes = plt.subplots(1,1)#, figsize=(13,18))  
plt.tight_layout()  


axes.spines['right'].set_visible(False)
axes.spines['top'].set_visible(False)
for axis in ['top','bottom','left','right']:
    axes.spines[axis].set_linewidth(1.5)

#axes.ticklabel_format(axis="x", style="scientific",scilimits=(0,0),useMathText=True)

axes.fill_between(k_1500, density_inf_1500+density_inf_S_1500, density_inf_1500-density_inf_S_1500, color="lightblue", alpha=0.5)
#axes.fill_between(k_5000, density_inf_5000-density_inf_5000_S, density_inf_5000+density_inf_5000_S, color="bisque", alpha=0.5)
#axes.fill_between(k_7200, density_inf_7200+density_inf_7200_S, density_inf_7200-density_inf_7200_S, color="darkseagreen", alpha=0.4)
axes.plot(k_1500,density_inf_1500,label="1500");
#axes.plot(k_5000,density_inf_5000,label="5000");
#axes.plot(k_7200,density_inf_7200,label="7200");
axes.set_xlabel(r"radius [$\mu m$]",fontsize=15)
axes.set_ylabel(r"density [$\frac{1}{\mu m^2}$]",fontsize=15);
#axes.set_xscale("log")
axes.set_yscale("log")


def e_func2 (x,L,a,n):
    return a*np.exp(-((x)**n)/L)


#popt,pcov = curve_fit(e_func2,k_5000[:50], density_inf_5000[:50],p0=[2,0.28,0.5])
#plt.plot(k_5000[:50],e_func2(k_5000[:50],*popt), label=r"$t^2$", color="black", linestyle = "--", linewidth=2);

#ppp=[1,1,0.39]
#x=np.arange(0,1118,1)
#plt.plot(x[4:],e_func2(x[4:],*ppp), color="black", linestyle = "--", linewidth=2);
axes.legend(loc="center right");

axes.text(500,10**-3,r"$ a\cdot exp(-(\frac{x}{\xi})^\beta)$", fontsize=15)


#fig.savefig("figures/over_time/Dichte_01/density_fit.png",bbox_inches = "tight",dpi=200)
#fig.savefig("figures/over_time/Dichte_01/density.pdf",bbox_inches = "tight", dpi=1200)
# Out:
# Text(500, 0.001, '$ a\\cdot exp(-(\\frac{x}{\\xi})^\\beta)$')

# %%
k_3200=np.arange(0,radius_3200,radius_3200/len(density_inf_3200))
k_5000=np.arange(0,radius_5000,radius_5000/len(density_inf_5000))
k_7200=np.arange(0,radius_7200,radius_7200/len(density_inf_7200))

plt.rc('xtick',labelsize=13)
plt.rc('ytick',labelsize=13)
t_end=10**-3

fig, axes = plt.subplots(1,1)#, figsize=(13,18))  
plt.tight_layout()  


axes.spines['right'].set_visible(False)
axes.spines['top'].set_visible(False)
for axis in ['top','bottom','left','right']:
    axes.spines[axis].set_linewidth(1.5)

#axes.ticklabel_format(axis="x", style="scientific",scilimits=(0,0),useMathText=True)

axes.fill_between(k_3200, density_inf_3200+density_inf_3200_S, density_inf_3200-density_inf_3200_S, color="lightblue", alpha=0.5)
axes.fill_between(k_5000, density_inf_5000-density_inf_5000_S, density_inf_5000+density_inf_5000_S, color="bisque", alpha=0.5)
axes.fill_between(k_7200, density_inf_7200+density_inf_7200_S, density_inf_7200-density_inf_7200_S, color="darkseagreen", alpha=0.4)
axes.plot(k_3200,density_inf_3200,label="3200");
axes.plot(k_5000,density_inf_5000,label="5000");
axes.plot(k_7200,density_inf_7200,label="7200");
axes.set_xlabel(r"radius [$\mu m$]",fontsize=15)
axes.set_ylabel(r"density [$\frac{1}{\mu m^2}$]",fontsize=15);
#axes.set_xscale("log")
axes.set_yscale("log")


def e_func2 (x,L,a,c,n):
    return a*np.exp(-((x-c)**n)/L)

#popt,pcov = curve_fit(powerlaw,k_5000, density_inf_5000,p0=[10000,4])
#plt.plot(k_5000,powerlaw(k_5000,*popt), label=r"$t^2$", color="black", linestyle = "--", linewidth=2);

#popt,pcov = curve_fit(e_func2,k_5000, density_inf_5000,p0=[1,1,0,0.39])
#plt.plot(k_5000,e_func2(k_5000,*popt), label=r"$t^2$", color="black", linestyle = "--", linewidth=2);

ppp=[1,1,0,0.39]
plt.plot(k_5000,e_func2(k_5000,*ppp), label=r"$a\cdot exp(-(\frac{x}{\xi})^\alpha)$", color="black", linestyle = "--", linewidth=2);
axes.legend(loc="center right");

#fig.savefig("figures/over_time/Dichte_01/density.png",bbox_inches = "tight")
#fig.savefig("figures/over_time/Dichte_01/density.pdf",bbox_inches = "tight", dpi=1200)
