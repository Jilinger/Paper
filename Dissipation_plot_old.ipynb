# %%
#Ode Solver
from qutip import *
from scipy.integrate import ode
from scipy.integrate import solve_ivp
from odeintw import odeintw



import math
import random
import numpy as np
import scipy.spatial
import matplotlib.pyplot as plt
import matplotlib
from matplotlib import animation
from numpy import linalg as LA
import copy
import time
import gc
# %load_ext memory_profiler

# %%
density=0.01

# %%
number_atoms=500
gamma_khz=50.0
r_b=2.5
radius= (np.sqrt(number_atoms*r_b**2/density))
print("radius=",radius)
times=np.logspace(-8,-3,100)
data = open("/home/jp/Dokumente/Bachelorarbeit/Mein_paper/BwHpcCluster/Results/Dissipation/normal_"+str(number_atoms)+"_"+str(np.round(density,3))+"_"+str(gamma_khz)+".npy","rb")

text_10=np.load(data)
print(text_10)
r_1_normal_10=np.load(data) 
r_2_normal_10=np.load(data) 
density_normal_10=np.load(data) 
density_inf_normal_10=np.load(data) 
ipr_normal_10=np.load(data) 
n_intervall_inf_normal_10=np.load(data) 
deviation_normal_10=np.load(data) 
distribution_width_normal_10=np.load(data) 
r_1_normal_S_10=np.load(data) 
r_2_normal_S_10=np.load(data) 
density_normal_S_10=np.load(data) 
density_inf_normal_S_10=np.load(data) 
ipr_normal_S_10=np.load(data) 
n_intervall_inf_normal_S_10=np.load(data) 
deviation_normal_S_10=np.load(data) 
distribution_width_normal_S_10=np.load(data) 

data = open("/home/jp/Dokumente/Bachelorarbeit/Mein_paper/BwHpcCluster/Results/Dissipation/dissipation_"+str(number_atoms)+"_"+str(np.round(density,3))+"_"+str(gamma_khz)+".npy","rb")
text_10=np.load(data)
r_1_diss_10=np.load(data) 
r_2_diss_10=np.load(data) 
density_diss_10=np.load(data) 
density_inf_diss_10=np.load(data) 
ipr_diss_10=np.load(data) 
n_intervall_inf_diss_10=np.load(data) 
deviation_diss_10=np.load(data) 
distribution_width_diss_10=np.load(data)
r_1_diss_S_10=np.load(data) 
r_2_diss_S_10=np.load(data) 
density_diss_S_10=np.load(data) 
density_inf_diss_S_10=np.load(data) 
ipr_diss_S_10=np.load(data) 
n_intervall_inf_diss_S_10=np.load(data) 
deviation_diss_S_10=np.load(data) 
distribution_width_diss_S_10=np.load(data)
# Out:
# radius= 559.0169943749474
# density=0.01, number_atoms=500, gamma=50.0, tend= 0.001

# %%
gamma_khz=50
data = open("/home/jp/Dokumente/Bachelorarbeit/Mein_paper/BwHpcCluster/Results/Dissipation/normal_"+str(number_atoms)+"_"+str(np.round(density,3))+"_"+str(gamma_khz)+".npy","rb")

text_50=np.load(data)
print(text_50)
r_1_normal_50=np.load(data) 
r_2_normal_50=np.load(data) 
density_normal_50=np.load(data) 
density_inf_normal_50=np.load(data) 
ipr_normal_50=np.load(data) 
n_intervall_inf_normal_50=np.load(data) 
deviation_normal_50=np.load(data) 
distribution_width_normal_50=np.load(data) 
r_1_normal_S_50=np.load(data) 
r_2_normal_S_50=np.load(data) 
density_normal_S_50=np.load(data) 
density_inf_normal_S_50=np.load(data) 
ipr_normal_S_50=np.load(data) 
n_intervall_inf_normal_S_50=np.load(data) 
deviation_normal_S_50=np.load(data) 
distribution_width_normal_S_50=np.load(data) 

data= open("/home/jp/Dokumente/Bachelorarbeit/Mein_paper/BwHpcCluster/Results/Dissipation/dissipation_"+str(number_atoms)+"_"+str(np.round(density,3))+"_"+str(gamma_khz)+".npy","rb")
text_50=np.load(data)
r_1_diss_50=np.load(data) 
r_2_diss_50=np.load(data) 
density_diss_50=np.load(data) 
density_inf_diss_50=np.load(data) 
ipr_diss_50=np.load(data) 
n_intervall_inf_diss_50=np.load(data) 
deviation_diss_50=np.load(data) 
distribution_width_diss_50=np.load(data)
r_1_diss_S_50=np.load(data) 
r_2_diss_S_50=np.load(data) 
density_diss_S_50=np.load(data) 
density_inf_diss_S_50=np.load(data) 
ipr_diss_S_50=np.load(data) 
n_intervall_inf_diss_S_50=np.load(data) 
deviation_diss_S_50=np.load(data) 
distribution_width_diss_S_50=np.load(data)
# Out:
# density=0.1, number_atoms=500, gamma=50, tend= 0.001

# %%
gamma_khz=100
data = open("/home/jp/Dokumente/Bachelorarbeit/Mein_paper/BwHpcCluster/Results/Dissipation/normal_"+str(number_atoms)+"_"+str(np.round(density,3))+"_"+str(gamma_khz)+".npy","rb")

text_100=np.load(data)
print(text_100)
r_1_normal_100=np.load(data) 
r_2_normal_100=np.load(data) 
density_normal_100=np.load(data) 
density_inf_normal_100=np.load(data) 
ipr_normal_100=np.load(data) 
n_intervall_inf_normal_100=np.load(data) 
deviation_normal_100=np.load(data) 
distribution_width_normal_100=np.load(data) 
r_1_normal_S_100=np.load(data) 
r_2_normal_S_100=np.load(data) 
density_normal_S_100=np.load(data) 
density_inf_normal_S_100=np.load(data) 
ipr_normal_S_100=np.load(data) 
n_intervall_inf_normal_S_100=np.load(data) 
deviation_normal_S_100=np.load(data) 
distribution_width_normal_S_100=np.load(data) 

data= open("/home/jp/Dokumente/Bachelorarbeit/Mein_paper/BwHpcCluster/Results/Dissipation/dissipation_"+str(number_atoms)+"_"+str(np.round(density,3))+"_"+str(gamma_khz)+".npy","rb")
text_100=np.load(data)
r_1_diss_100=np.load(data) 
r_2_diss_100=np.load(data) 
density_diss_100=np.load(data) 
density_inf_diss_100=np.load(data) 
ipr_diss_100=np.load(data) 
n_intervall_inf_diss_100=np.load(data) 
deviation_diss_100=np.load(data) 
distribution_width_diss_100=np.load(data)
r_1_diss_S_100=np.load(data) 
r_2_diss_S_100=np.load(data) 
density_diss_S_100=np.load(data) 
density_inf_diss_S_100=np.load(data) 
ipr_diss_S_100=np.load(data) 
n_intervall_inf_diss_S_100=np.load(data) 
deviation_diss_S_100=np.load(data) 
distribution_width_diss_S_100=np.load(data)
# Out:
# density=0.1, number_atoms=500, gamma=100, tend= 0.001

# %%
d_r=2*r_b

x=np.arange(0,int(radius-d_r),d_r)

fig, axes = plt.subplots(3,2, figsize=(13,10))  # 2 rows, 2 columns
plt.tight_layout()  
plt.subplots_adjust(wspace=0.2)


#axes[1,0].ticklabel_format(axis="x", style="scientific",scilimits=(4,-3))
axes[0,0].set_title("standard deviation  "+ r"$<r^2>-<r>^2$")
axes[0,0].plot(times, deviation_normal_10,label="Ohne Dissipation")
axes[0,0].plot(times, deviation_diss_10,label="Mit Dissipation")
axes[0,0].set_yscale("log")
axes[0,0].set_xscale("log")
axes[0,0].set_xlabel("Zeit")
axes[0,0].set_ylabel(r"$\sigma$")
axes[0,0].legend();


axes[0,1].set_title("distribution width")
axes[0,1].ticklabel_format(axis="x", style="scientific",scilimits=(4,-3))
axes[0,1].plot(times,distribution_width_normal_10,label="Ohne Dissipation");
axes[0,1].plot(times,distribution_width_diss_10,label="Mit Dissipation");
axes[0,1].set_xlabel("Zeit")
axes[0,1].set_ylabel("Radius");
axes[0,1].legend();
fig.tight_layout()



axes[1,1].set_title("Participation ratio")
axes[1,1].ticklabel_format(axis="x", style="scientific",scilimits=(4,-3))
axes[1,1].plot(times,ipr_normal_10,label="Ohne Dissipation");
axes[1,1].plot(times,ipr_diss_10,label="Mit Dissipation");
axes[1,1].fill_between(times, ipr_normal_10-ipr_normal_S_10, ipr_normal_10+ipr_normal_S_10, color="lightblue", alpha=0.5)
axes[1,1].fill_between(times, ipr_diss_10-ipr_diss_S_10, ipr_diss_10+ipr_diss_S_10, color="orange", alpha=0.5)
axes[1,1].set_xlabel("Zeit")
axes[1,1].set_ylabel("states");
axes[1,1].legend();


axes[1,0].set_title("r_2")
axes[1,0].set_yscale("log")
axes[1,0].set_xscale("log")
#axes[1,0].set_ylim(1,0.5*radius**2)
#axes[1,0].plot(times,quad_func(times,0.1), label=r"$t^2$", color="black", linestyle = "--");
axes[1,0].fill_between(times, r_2_normal_10-r_2_normal_S_10, r_2_normal_10+r_2_normal_S_10, color="lightblue", alpha=0.5)
axes[1,0].fill_between(times, r_2_diss_10-r_2_diss_S_10, r_2_diss_10+r_2_diss_S_10, color="orange", alpha=0.5)
axes[1,0].plot(times,r_2_normal_10,label="Ohne Dissipation");
axes[1,0].plot(times[1:],r_2_diss_10[1:],label="Mit Dissipation");
axes[1,0].set_xlabel("Zeit")
axes[1,0].set_ylabel("Abstand");
axes[1,0].legend();



axes[2,0].set_title("r_1")
#axes[2,0].set_yscale("log")
#axes[2,0].set_xscale("log")
#axes[2,0].ticklabel_format(axis="x", style="scientific",scilimits=(4,-3))
#axes[2,0].set_ylim(1,radius)
axes[2,0].plot(times,r_1_normal_10,label="Ohne Dissipation");
axes[2,0].plot(times,r_1_diss_10,label="Mit Dissipation");
axes[2,0].set_xlabel("Zeit")
axes[2,0].set_ylabel("Abstand");
axes[2,0].legend();


fig, axes = plt.subplots(2,2, figsize=(13,6))  # 2 rows, 2 columns
plt.subplots_adjust(wspace=0.4,hspace=0.4)


axes[0,0].set_title("radial density area")
axes[0,0].plot(x,n_intervall_inf_normal_10, label="Ohne Dissipation");
axes[0,0].plot(x,n_intervall_inf_diss_10,label="Mit Dissipation");
axes[0,0].set_xlabel("Abstand")
axes[0,0].set_ylabel("Dichte")
axes[0,0].set_yscale("log")
axes[0,0].legend();


axes[0,1].set_title("radial density atoms")
#axes[0,1].ticklabel_format(axis="x", style="scientific",scilimits=(4,-3))
axes[0,1].plot(x,density_inf_normal_10,label="Ohne Dissipation");
axes[0,1].plot(x,density_inf_diss_10,label="Mit Dissipation");
axes[0,1].set_xlabel("Abstand")
axes[0,1].set_ylabel("Dichte");
axes[0,1].set_yscale("log")
axes[0,1].legend();


axes[1,0].set_title("radial density atoms - log log")
axes[1,0].plot(x,density_inf_normal_10,label="Ohne Dissipation");
axes[1,0].plot(x,density_inf_diss_10,label="Mit Dissipation");
axes[1,0].set_xlabel("Abstand")
axes[1,0].set_ylabel("Dichte")
axes[1,0].set_yscale("log")
axes[1,0].set_xscale("log")
axes[1,0].legend();

axes[1,1].set_title("radial density - mittlere Zeiten")
axes[1,1].plot(x,density_normal_10,label="Ohne Dissipation");
axes[1,1].plot(x,density_diss_10,label="Mit Dissipation");
axes[1,1].set_xlabel("Abstand")
axes[1,1].set_ylabel("Dichte")
axes[1,1].set_yscale("log")
axes[1,1].set_xscale("log")
axes[1,1].legend();
# Out:
# /home/jp/.local/lib/python3.5/site-packages/numpy/core/numeric.py:538: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# /home/jp/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:5108: ComplexWarning: Casting complex values to real discards the imaginary part
#   X[0] = start
# /home/jp/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:5109: ComplexWarning: Casting complex values to real discards the imaginary part
#   X[N + 1] = end
# /home/jp/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:5112: ComplexWarning: Casting complex values to real discards the imaginary part
#   X[1:N + 1, 1] = y1slice
# /home/jp/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:5114: ComplexWarning: Casting complex values to real discards the imaginary part
#   X[N + 2:, 1] = y2slice[::-1]

# %%
d_r=2*r_b

x=np.arange(0,int(radius-d_r),d_r)
fig, axes = plt.subplots(2,2, figsize=(13,10)) 

axes[0,0].set_title("r_2")
axes[0,0].set_yscale("log")
axes[0,0].set_xscale("log")
#axes[0,0].set_ylim(1,0.5*radius**2)
#axes[0,0].plot(times,quad_func(times,0.1), label=r"$t^2$", color="black", linestyle = "--");
#axes[0,0].fill_between(times, r_2_diss_10-r_2_diss_S_10, r_2_diss_10+r_2_diss_S_10, color="orange", alpha=0.5)
axes[0,0].plot(times,r_2_normal_10,label="Ohne");
axes[0,0].plot(times,r_2_normal_50,label="Ohne");
axes[0,0].plot(times,r_2_normal_100,label="Ohne");
axes[0,0].plot(times[1:],r_2_diss_10[1:],label="10 kHz");
axes[0,0].plot(times[1:],r_2_diss_50[1:],label="50 kHz");
axes[0,0].plot(times[1:],r_2_diss_100[1:],label="100 kHz");

axes[0,0].plot([10**-8,1.7*10**-3],[0.5*radius**2,0.5*radius**2],linestyle ="--", color= "grey")
axes[0,0].set_xlabel("Zeit")
axes[0,0].set_ylabel("Abstand");
axes[0,0].legend();

axes[0,1].set_title("Participation ratio")
axes[0,1].ticklabel_format(axis="x", style="scientific",scilimits=(4,-3))
axes[0,1].plot(times,ipr_normal_10,label="Ohne");
axes[0,1].plot(times,ipr_normal_50,label="Ohne");
axes[0,1].plot(times,ipr_normal_100,label="Ohne");
axes[0,1].plot(times,ipr_diss_10,label="10 kHz");
axes[0,1].plot(times,ipr_diss_50,label="50 kHz");
axes[0,1].plot(times,ipr_diss_100,label="100 kHz");
axes[0,1].set_xlabel("Zeit")
axes[0,1].set_ylabel("states");
axes[0,1].legend();


axes[1,0].set_title("radial density atoms - log log")
axes[1,0].plot(x,density_inf_normal_10,label="Ohne ");
axes[1,0].plot(x,density_inf_normal_50,label="Ohne ");
axes[1,0].plot(x,density_inf_normal_100,label="Ohne ");
axes[1,0].plot(x,density_inf_diss_10,label="10 kHz");
axes[1,0].plot(x,density_inf_diss_50,label="50 kHz");
axes[1,0].plot(x,density_inf_diss_100,label="100 kHz");
axes[1,0].set_xlabel("Abstand")
axes[1,0].set_ylabel("Dichte")
axes[1,0].set_yscale("log")
axes[1,0].set_xscale("log")
axes[1,0].legend();

# %%
print(4*10**7/10**12)
density=0.01
radius= (np.sqrt(number_atoms*r_b**2/density))
print(radius)
print(500/(4/3*np.pi*radius**3))
# Out:
# 4e-05
# 559.0169943749474
# 6.832920416804901e-07
